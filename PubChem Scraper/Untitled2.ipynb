# %%
import pandas as pd

# %%
df1 = pd.read_csv("missing_eight.csv")
df2 = pd.read_csv("corrected_pubchem_data_final_3.csv", index_col=[0])

# %%
df1
# Out:
#   Original Molecule Parsed Molecule  \
# 0      GEMIFLOXACIN    GEMIFLOXACIN
# 1        VILAZODONE      VILAZODONE
# 2       DIPIVEFRINE     DIPIVEFRINE
# 3      TESTOSTERONE    TESTOSTERONE
# 4         EDARAVONE       EDARAVONE
# 5         DONEPEZIL       DONEPEZIL
# 6           ETHANOL         ETHANOL
# 7       BEPOTASTINE     BEPOTASTINE
# 8        DOFETILIDE      DOFETILIDE
#
#                                                 Link Result Type  \
# 0  https://pubchem.ncbi.nlm.nih.gov/compound/9571107    FEATURED
# 1  https://pubchem.ncbi.nlm.nih.gov/compound/6918314    FEATURED
# 2     https://pubchem.ncbi.nlm.nih.gov/compound/3105    FEATURED
# 3     https://pubchem.ncbi.nlm.nih.gov/compound/6013    FEATURED
# 4     https://pubchem.ncbi.nlm.nih.gov/compound/4021    FEATURED
# 5     https://pubchem.ncbi.nlm.nih.gov/compound/3152    FEATURED
# 6      https://pubchem.ncbi.nlm.nih.gov/compound/702    FEATURED
# 7   https://pubchem.ncbi.nlm.nih.gov/compound/164522    FEATURED
# 8    https://pubchem.ncbi.nlm.nih.gov/compound/71329    FEATURED
#
#                                                  CAS  \
# 0                           175463-14-6, 210353-54-1
# 1                                        163521-12-8
# 2                                         52365-63-6
# 3                                            58-22-0
# 4                       89-25-8, 19735-89-8, 89-25-8
# 5                                        120014-06-4
# 6  64-17-5, 68476-78-8, 1702-17-6, 68475-56-9, 21...
# 7                          125602-71-3, 1070505-53-1
# 8                                        115256-11-6
#
#                                       Deprecated CAS Compound/Substance  \
# 0              204519-64-2, 210353-52-9, 214346-11-9           COMPOUND
# 1                                        No CAS info           COMPOUND
# 2                                        No CAS info           COMPOUND
# 3                                       1050678-68-6           COMPOUND
# 4  115566-83-1, 12235-58-4, 206195-95-1, 52224-17...           COMPOUND
# 5                                        No CAS info           COMPOUND
# 6  121182-78-3, 8000-16-6, 8024-45-1, 8000-16-6, ...           COMPOUND
# 7                                        No CAS info           COMPOUND
# 8                                        No CAS info           COMPOUND
#
#   Depositor Synonym List Regular Synonym List Synonym?
# 0                    YES                  YES      YES
# 1                    YES                  YES      YES
# 2                    YES                  YES      YES
# 3                    YES                  YES      YES
# 4                    YES                  YES      YES
# 5                    YES                  YES      YES
# 6                    YES                  YES      YES
# 7                    YES                  YES      YES
# 8                    YES                  YES      YES

# %%
df2
# Out:
#                                Original Molecule  \
# Unnamed: 0
# 0                      1-2-PROPANEDIOL_DIACETATE
# 1                                  1-HEXADECANOL
# 2                                  1-OCTADECANOL
# 3           2-3-(2-IODOPROPYLIDENEDIOXY)PROPANOL
# 4                             2-OXOGLUTARIC_ACID
# ...                                          ...
# 2900                             ZIZYPHUS_JUJUBA
# 2901                             ZOLEDRONIC_ACID
# 2902                                ZOLMITRIPTAN
# 2903                                    ZOLPIDEM
# 2904                                  ZONISAMIDE
#
#                                  Parsed Molecule  \
# Unnamed: 0
# 0                      1,2 PROPANEDIOL DIACETATE
# 1                                  1 HEXADECANOL
# 2                                  1 OCTADECANOL
# 3           2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# 4                             2 OXOGLUTARIC ACID
# ...                                          ...
# 2900                             ZIZYPHUS JUJUBA
# 2901                             ZOLEDRONIC ACID
# 2902                                ZOLMITRIPTAN
# 2903                                    ZOLPIDEM
# 2904                                  ZONISAMIDE
#
#                                                          Link Result Type  \
# Unnamed: 0
# 0             https://pubchem.ncbi.nlm.nih.gov/compound/12198    RELEVANT
# 1              https://pubchem.ncbi.nlm.nih.gov/compound/2682    RELEVANT
# 2              https://pubchem.ncbi.nlm.nih.gov/compound/8221    RELEVANT
# 3                                                     No Link   Not Found
# 4                https://pubchem.ncbi.nlm.nih.gov/compound/51    FEATURED
# ...                                                       ...         ...
# 2900        https://pubchem.ncbi.nlm.nih.gov/substance/482...    RELEVANT
# 2901          https://pubchem.ncbi.nlm.nih.gov/compound/68740    FEATURED
# 2902          https://pubchem.ncbi.nlm.nih.gov/compound/60857    FEATURED
# 2903           https://pubchem.ncbi.nlm.nih.gov/compound/5732    FEATURED
# 2904           https://pubchem.ncbi.nlm.nih.gov/compound/5734    FEATURED
#
#                                          CAS  \
# Unnamed: 0
# 0                                   623-84-7
# 1           36653-82-4, 36311-34-9, 124-29-8
# 2                       112-92-5, 26762-44-7
# 3                                No CAS info
# 4           328-50-7, 34410-46-3, 17091-15-5
# ...                                      ...
# 2900                             No CAS info
# 2901                             118072-93-8
# 2902                             139264-17-8
# 2903                              82626-48-0
# 2904                              68291-97-4
#
#                                                Deprecated CAS  \
# Unnamed: 0
# 0                                   134236-23-0, 1432741-27-9
# 1           168679-13-8, 1173838-87-3, 124-29-8, 55069-45-...
# 2           193766-48-2, 8014-37-7, 8032-19-7, 8032-21-1, ...
# 3                                                 No CAS info
# 4                                                  27175-99-1
# ...                                                       ...
# 2900                                              No CAS info
# 2901                                              No CAS info
# 2902                                              No CAS info
# 2903                                              No CAS info
# 2904                                              No CAS info
#
#            Compound/Substance Depositor Synonym List Regular Synonym List  \
# Unnamed: 0
# 0                    COMPOUND                    YES                  YES
# 1                    COMPOUND                    YES                  YES
# 2                    COMPOUND                    YES                  YES
# 3                     NEITHER                MISSING              MISSING
# 4                    COMPOUND                    YES                  YES
# ...                       ...                    ...                  ...
# 2900                SUBSTANCE                     NO              MISSING
# 2901                 COMPOUND                    YES                  YES
# 2902                 COMPOUND                    YES                  YES
# 2903                 COMPOUND                    YES                  YES
# 2904                 COMPOUND                    YES                  YES
#
#            Synonym?
# Unnamed: 0
# 0               YES
# 1               YES
# 2               YES
# 3                NO
# 4               YES
# ...             ...
# 2900             NO
# 2901            YES
# 2902            YES
# 2903            YES
# 2904            YES
#
# [2905 rows x 10 columns]

# %%
import pandas as pd

merged_df = pd.merge(df2, df1, on=['Original Molecule', 'Parsed Molecule'], how='left', suffixes=('_df2', '_df1'))

# Drop unnecessary columns from df1 (suffix _df1) and rename columns from df2 (suffix _df2)
merged_df.drop(columns=[col for col in merged_df.columns if '_df1' in col], inplace=True)
merged_df.rename(columns={col: col.replace('_df2', '') for col in merged_df.columns}, inplace=True)

# Display the merged dataframe
merged_df
# Out:
#                          Original Molecule  \
# 0                1-2-PROPANEDIOL_DIACETATE
# 1                            1-HEXADECANOL
# 2                            1-OCTADECANOL
# 3     2-3-(2-IODOPROPYLIDENEDIOXY)PROPANOL
# 4                       2-OXOGLUTARIC_ACID
# ...                                    ...
# 2900                       ZIZYPHUS_JUJUBA
# 2901                       ZOLEDRONIC_ACID
# 2902                          ZOLMITRIPTAN
# 2903                              ZOLPIDEM
# 2904                            ZONISAMIDE
#
#                            Parsed Molecule  \
# 0                1,2 PROPANEDIOL DIACETATE
# 1                            1 HEXADECANOL
# 2                            1 OCTADECANOL
# 3     2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# 4                       2 OXOGLUTARIC ACID
# ...                                    ...
# 2900                       ZIZYPHUS JUJUBA
# 2901                       ZOLEDRONIC ACID
# 2902                          ZOLMITRIPTAN
# 2903                              ZOLPIDEM
# 2904                            ZONISAMIDE
#
#                                                    Link Result Type  \
# 0       https://pubchem.ncbi.nlm.nih.gov/compound/12198    RELEVANT
# 1        https://pubchem.ncbi.nlm.nih.gov/compound/2682    RELEVANT
# 2        https://pubchem.ncbi.nlm.nih.gov/compound/8221    RELEVANT
# 3                                               No Link   Not Found
# 4          https://pubchem.ncbi.nlm.nih.gov/compound/51    FEATURED
# ...                                                 ...         ...
# 2900  https://pubchem.ncbi.nlm.nih.gov/substance/482...    RELEVANT
# 2901    https://pubchem.ncbi.nlm.nih.gov/compound/68740    FEATURED
# 2902    https://pubchem.ncbi.nlm.nih.gov/compound/60857    FEATURED
# 2903     https://pubchem.ncbi.nlm.nih.gov/compound/5732    FEATURED
# 2904     https://pubchem.ncbi.nlm.nih.gov/compound/5734    FEATURED
#
#                                    CAS  \
# 0                             623-84-7
# 1     36653-82-4, 36311-34-9, 124-29-8
# 2                 112-92-5, 26762-44-7
# 3                          No CAS info
# 4     328-50-7, 34410-46-3, 17091-15-5
# ...                                ...
# 2900                       No CAS info
# 2901                       118072-93-8
# 2902                       139264-17-8
# 2903                        82626-48-0
# 2904                        68291-97-4
#
#                                          Deprecated CAS Compound/Substance  \
# 0                             134236-23-0, 1432741-27-9           COMPOUND
# 1     168679-13-8, 1173838-87-3, 124-29-8, 55069-45-...           COMPOUND
# 2     193766-48-2, 8014-37-7, 8032-19-7, 8032-21-1, ...           COMPOUND
# 3                                           No CAS info            NEITHER
# 4                                            27175-99-1           COMPOUND
# ...                                                 ...                ...
# 2900                                        No CAS info          SUBSTANCE
# 2901                                        No CAS info           COMPOUND
# 2902                                        No CAS info           COMPOUND
# 2903                                        No CAS info           COMPOUND
# 2904                                        No CAS info           COMPOUND
#
#      Depositor Synonym List Regular Synonym List Synonym?
# 0                       YES                  YES      YES
# 1                       YES                  YES      YES
# 2                       YES                  YES      YES
# 3                   MISSING              MISSING       NO
# 4                       YES                  YES      YES
# ...                     ...                  ...      ...
# 2900                     NO              MISSING       NO
# 2901                    YES                  YES      YES
# 2902                    YES                  YES      YES
# 2903                    YES                  YES      YES
# 2904                    YES                  YES      YES
#
# [2905 rows x 10 columns]

# %%
merged_df.to_csv('final_corrected_pubchem.csv', index=False)
