# %%
import pandas as pd

# %%
correct_data = pd.read_csv("pubchem_longer_wait.csv")

# %%
old_data = pd.read_csv("PUBCHEM_SYNONYMS_FLAGGED.csv")
old_data
# Out:
#                          Original Molecule  \
# 0                1-2-PROPANEDIOL_DIACETATE
# 1                            1-HEXADECANOL
# 2                            1-OCTADECANOL
# 3     2-3-(2-IODOPROPYLIDENEDIOXY)PROPANOL
# 4                       2-OXOGLUTARIC_ACID
# ...                                    ...
# 2900                       ZIZYPHUS_JUJUBA
# 2901                       ZOLEDRONIC_ACID
# 2902                          ZOLMITRIPTAN
# 2903                              ZOLPIDEM
# 2904                            ZONISAMIDE
#
#                            Parsed Molecule  \
# 0                1,2 PROPANEDIOL DIACETATE
# 1                            1 HEXADECANOL
# 2                            1 OCTADECANOL
# 3     2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# 4                       2 OXOGLUTARIC ACID
# ...                                    ...
# 2900                       ZIZYPHUS JUJUBA
# 2901                       ZOLEDRONIC ACID
# 2902                          ZOLMITRIPTAN
# ...

# %%
merged_df = pd.merge(old_data, correct_data, how='inner')
merged_df
# Out:
#     Original Molecule Parsed Molecule  \
# 0       ABALOPARATIDE   ABALOPARATIDE
# 1           ABATACEPT       ABATACEPT
# 2          ACEBUTOLOL      ACEBUTOLOL
# 3           ACEMANNAN       ACEMANNAN
# 4       ACETAZOLAMIDE   ACETAZOLAMIDE
# ..                ...             ...
# 344        VIGABATRIN      VIGABATRIN
# 345      VORICONAZOLE    VORICONAZOLE
# 346      VOXILAPREVIR    VOXILAPREVIR
# 347        ZEAXANTHIN      ZEAXANTHIN
# 348          ZILEUTON        ZILEUTON
#
#                                                   Link Result Type  \
# 0    https://pubchem.ncbi.nlm.nih.gov/compound/Abal...    FEATURED
# 1    https://pubchem.ncbi.nlm.nih.gov/compound/Abat...    FEATURED
# 2       https://pubchem.ncbi.nlm.nih.gov/compound/1978    FEATURED
# 3      https://pubchem.ncbi.nlm.nih.gov/compound/72041    FEATURED
# 4       https://pubchem.ncbi.nlm.nih.gov/compound/1986    FEATURED
# ..                                                 ...         ...
# ...

# %%
sample1 = correct_data.sample(30)
sample1
# Out:
#                                     Original Molecule  \
# 523                                       CHLOROPHYLL
# 843                               DOCOSAHEXANOIC ACID
# 1545                                       LISINOPRIL
# 1634                           MELALEUCA ALTERNIFOLIA
# 781                                          DIASTASE
# 1523                                      LEVORPHANOL
# 2376                        SCHOENOCAULON OFFICINALIS
# 2229                                         PYRANTEL
# 2356                                        SALSALATE
# 16                                        ABEMACICLIB
# 668                                          CREATINE
# 1415                                    ISOCARBOXAZID
# 756                                       DESIPRAMINE
# 118                                 AMINOCAPROIC ACID
# 1387                                           INULIN
# 2215                         PRUNUS AMYGDALUS (AMARA)
# ...

# %%
sample2 = correct_data.sample(30)
sample2
# Out:
#                                 Original Molecule  \
# 681                               CUCUMIS SATIVUS
# 2047                                       PHENOL
# 2258                                  RANIBIZUMAB
# 1372  INSULIN HUMAN ZINC SUSPENSION (CRYSTALLINE)
# 1111                                FOSAPREPITANT
# 712                                  DALFOPRISTIN
# 2097                                 PIPER LONGUM
# 433                                 CARBONIC ACID
# 2799                        VACCINIUM MACROCARPON
# 2786              VACCINE- PNEUMOCOCCAL CONJUGATE
# 2613                              THROAT LOZENGES
# 741                                  DELAFLOXACIN
# 871                      DROMAIUS NOVAEHOLLANDIAE
# 1220                                     GUAIACOL
# 1208                                    GOLIMUMAB
# 1804                                   NELARABINE
# 2596                                   TEZACAFTOR
# 1653                                   MEPYRAMINE
# ...

# %%
sample3 = correct_data.sample(30)
sample3
# Out:
#                     Original Molecule                  Parsed Molecule  \
# 2869               WITHANIA SOMNIFERA               WITHANIA SOMNIFERA
# 1625              MEDICATED DRESSINGS              MEDICATED DRESSINGS
# 2575                      TERBINAFINE                      TERBINAFINE
# 2461                         SQUALANE                         SQUALANE
# 1138                     GADOFOSVESET                     GADOFOSVESET
# 1944            P-HYDROXYBENZOIC ACID            P-HYDROXYBENZOIC ACID
# 2432            SLIMMING PREPARATIONS            SLIMMING PREPARATIONS
# 517                     CHLORHEXIDINE                    CHLORHEXIDINE
# 2756  VACCINE-MENINGOCOCCAL CONJUGATE  VACCINE-MENINGOCOCCAL CONJUGATE
# 1225                       GUANFACINE                       GUANFACINE
# 2490         SUCROFERRIC OXYHYDROXIDE         SUCROFERRIC OXYHYDROXIDE
# 321                            BIOTIN                           BIOTIN
# ...

# %%
sample4 = correct_data.sample(30)
sample4
# Out:
#             Original Molecule          Parsed Molecule  \
# 736               DEFERIPRONE              DEFERIPRONE
# 2234    PYRIDOXAL 5 PHOSPHATE    PYRIDOXAL 5 PHOSPHATE
# 1367         INSULIN GLARGINE         INSULIN GLARGINE
# 1652              MEPROBAMATE              MEPROBAMATE
# 1703             METIPRANOLOL             METIPRANOLOL
# 1476               LAMIVUDINE               LAMIVUDINE
# 2533              TALAZOPARIB              TALAZOPARIB
# 2110                  PLASMIN                  PLASMIN
# 1289       HYDROXYCHLOROQUINE       HYDROXYCHLOROQUINE
# 1484            LAROTRECTINIB            LAROTRECTINIB
# 2899  ZIRCONIUM CYCLOSILICATE  ZIRCONIUM CYCLOSILICATE
# 1358      INOSITOL NICOTINATE      INOSITOL NICOTINATE
# 1554               LOFEXIDINE               LOFEXIDINE
# 1400            IOXAGLIC ACID            IOXAGLIC ACID
# 1815              NICARDIPINE              NICARDIPINE
# 2089           PINUS PINASTER           PINUS PINASTER
# ...

# %%
correct_data
# Out:
#                          Original Molecule  \
# 0                1,2 PROPANEDIOL DIACETATE
# 1                            1 HEXADECANOL
# 2                            1 OCTADECANOL
# 3     2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# 4                       2 OXOGLUTARIC ACID
# ...                                    ...
# 2900                       ZIZYPHUS JUJUBA
# 2901                       ZOLEDRONIC ACID
# 2902                          ZOLMITRIPTAN
# 2903                              ZOLPIDEM
# 2904                            ZONISAMIDE
#
#                            Parsed Molecule  \
# 0                1,2 PROPANEDIOL DIACETATE
# 1                            1 HEXADECANOL
# 2                            1 OCTADECANOL
# 3     2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# 4                       2 OXOGLUTARIC ACID
# ...                                    ...
# 2900                       ZIZYPHUS JUJUBA
# 2901                       ZOLEDRONIC ACID
# 2902                          ZOLMITRIPTAN
# ...
