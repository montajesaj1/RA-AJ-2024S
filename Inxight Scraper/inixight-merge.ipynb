# %%
import pandas as pd

# %%
main = pd.read_csv("inxight_corrected_cas.csv")
main
# Out:
#                        molecule          cas  \
# 0     1,2 PROPANEDIOL DIACETATE     623-84-7
# 1                 1 HEXADECANOL   36653-82-4
# 2                 1 OCTADECANOL     112-92-5
# 3            2 OXOGLUTARIC ACID     328-50-7
# 4                    2 PROPANOL      67-63-0
# ...                         ...          ...
# 2335    ZIRCONIUM CYCLOSILICATE   17141-74-1
# 2336            ZOLEDRONIC ACID  118072-93-8
# 2337               ZOLMITRIPTAN  139264-17-8
# 2338                   ZOLPIDEM   82626-48-0
# 2339                 ZONISAMIDE   68291-97-4
#
#                               best_match_url  results  \
# 0     https://drugs.ncats.io/drug/5Z492UNF9O        1
# 1     https://drugs.ncats.io/drug/936JST6JCN        1
# 2     https://drugs.ncats.io/drug/2KR89I4H1Y        1
# 3     https://drugs.ncats.io/drug/8ID597Z82X        1
# 4     https://drugs.ncats.io/drug/ND2M416302        1
# ...                                      ...      ...
# ...

# %%
second_cas = pd.read_csv("found_results_second.csv")
second_cas
# Out:
#                  molecule           cas  \
# 0    ACHILLEA MILLEFOLIUM     8022-07-9
# 1               ADAPALENE   106685-40-9
# 2          ALPHA CAROTENE     7488-99-5
# 3              ALPRAZOLAM    28981-97-7
# 4             ALPROSTADIL      745-65-3
# ..                    ...           ...
# 62  TRASTUZUMAB EMTANSINE  1018448-65-1
# 63       TRITICUM VULGARE     8006-95-9
# 64         TURPENTINE OIL     8006-64-2
# 65               XYLANASE     7554-16-7
# 66                 XYLOSE       58-86-6
#
#                             best_match_url  results  \
# 0   https://drugs.ncats.io/drug/97P5D0WG43        2
# 1   https://drugs.ncats.io/drug/1L4806J2QF        1
# 2   https://drugs.ncats.io/drug/45XWE1Z69V        1
# 3   https://drugs.ncats.io/drug/YU55MQ3IZY        1
# 4   https://drugs.ncats.io/drug/F5TD010360        1
# ..                                     ...      ...
# 62  https://drugs.ncats.io/drug/SE2KH7T06F        1
# 63  https://drugs.ncats.io/drug/14C97E680P        1
# ...

# %%
third_cas = pd.read_csv("found_results_third_real.csv")
third_cas
# Out:
#         molecule           cas                          best_match_url  \
# 0  ALPHA AMYLASE     1109-28-0  https://drugs.ncats.io/drug/639K0T34IK
# 1       DOLOMITE     7000-29-5  https://drugs.ncats.io/drug/UG9H2002BF
# 2   FURAZOLIDONE       67-45-8  https://drugs.ncats.io/drug/5J9CPU3RE0
# 3       NABILONE    51022-71-0  https://drugs.ncats.io/drug/2N4O9L084N
# 4    TALAZOPARIB  1373431-65-2  https://drugs.ncats.io/drug/02WK9U5NZC
# 5      VITAMIN F      506-32-1  https://drugs.ncats.io/drug/27YG812J1I
#
#    results                                          query_url query_type  \
# 0        1  https://drugs.ncats.io/substances?q=(root_code...   ONLY CAS
# 1        1  https://drugs.ncats.io/substances?q=(root_code...   ONLY CAS
# 2        1  https://drugs.ncats.io/substances?q=(root_code...   ONLY CAS
# 3        1  https://drugs.ncats.io/substances?q=(root_code...   ONLY CAS
# 4        1  https://drugs.ncats.io/substances?q=(root_code...   ONLY CAS
# ...

# %%
remaining = pd.read_csv("remaining.csv")
remaining
# Out:
#         Original Molecule        Parsed Molecule  \
# 0     ALPHA-GALACTOSIDASE    ALPHA-GALACTOSIDASE
# 1         ARALIA RACEMOSA        ARALIA RACEMOSA
# 2      ARANEUS DIADEMATUS     ARANEUS DIADEMATUS
# 3      AUROTHIOMALIC ACID     AUROTHIOMALIC ACID
# 4       BERBERIS VULGARIS      BERBERIS VULGARIS
# ..                    ...                    ...
# 68    TRIBULUS TERRESTRIS    TRIBULUS TERRESTRIS
# 69          URTICA DIOICA          URTICA DIOICA
# 70  VALERIANA OFFICINALIS  VALERIANA OFFICINALIS
# 71    VERBENA OFFICINALIS    VERBENA OFFICINALIS
# 72              VITAMIN K              VITAMIN K
#
#                                                  Link Result Type  \
# 0     https://pubchem.ncbi.nlm.nih.gov/compound/82000    RELEVANT
# 1   https://pubchem.ncbi.nlm.nih.gov/compound/Aral...    FEATURED
# 2   https://pubchem.ncbi.nlm.nih.gov/compound/Aran...    FEATURED
# 3    https://pubchem.ncbi.nlm.nih.gov/compound/422786    FEATURED
# ...

# %%
# Set 'molecule' as index for all DataFrames
main.set_index('molecule', inplace=True)
second_cas.set_index('molecule', inplace=True)
third_cas.set_index('molecule', inplace=True)

# Update rows in main with corresponding rows from second_cas and third_cas
main.update(second_cas)
main.update(third_cas)

# Reset index to have 'molecule' as a regular column again
main.reset_index(inplace=True)

# Save the updated DataFrame
main.to_csv("updated_main.csv", index=False)
