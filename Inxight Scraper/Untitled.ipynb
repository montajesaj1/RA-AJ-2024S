# %%
import pandas as pd

# %%
third = pd.read_csv("zero_results_third.csv")
molecules = pd.read_csv("../PubChem Scraper/pubchem_longer_wait_final.csv")

# %%
third_mol = third['molecule'].to_list()

# %%
molecules = molecules[molecules['Parsed Molecule'].isin(third_mol)]

# %%
molecules
# Out:
#           Original Molecule        Parsed Molecule  \
# 92      ALPHA-GALACTOSIDASE    ALPHA-GALACTOSIDASE
# 186         ARALIA RACEMOSA        ARALIA RACEMOSA
# 187      ARANEUS DIADEMATUS     ARANEUS DIADEMATUS
# 229      AUROTHIOMALIC ACID     AUROTHIOMALIC ACID
# 295       BERBERIS VULGARIS      BERBERIS VULGARIS
# ...                     ...                    ...
# 2690    TRIBULUS TERRESTRIS    TRIBULUS TERRESTRIS
# 2752          URTICA DIOICA          URTICA DIOICA
# 2805  VALERIANA OFFICINALIS  VALERIANA OFFICINALIS
# 2832    VERBENA OFFICINALIS    VERBENA OFFICINALIS
# 2851              VITAMIN K              VITAMIN K
#
#                                                    Link Result Type  \
# 92      https://pubchem.ncbi.nlm.nih.gov/compound/82000    RELEVANT
# 186   https://pubchem.ncbi.nlm.nih.gov/compound/Aral...    FEATURED
# 187   https://pubchem.ncbi.nlm.nih.gov/compound/Aran...    FEATURED
# 229    https://pubchem.ncbi.nlm.nih.gov/compound/422786    FEATURED
# ...

# %%
molecules.to_csv("remaining.csv", index = False)
