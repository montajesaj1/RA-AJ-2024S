# %%
import pandas as pd

# %%
pharm_df = pd.read_csv("final_data_labelled.csv")
pharm_df.head()
# Out:
#                       Original Molecule                       Parsed Molecule  \
# 0             1-2-PROPANEDIOL_DIACETATE             1,2 PROPANEDIOL DIACETATE
# 1                         1-HEXADECANOL                         1 HEXADECANOL
# 2                         1-OCTADECANOL                         1 OCTADECANOL
# 3  2-3-(2-IODOPROPYLIDENEDIOXY)PROPANOL  2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# 4                    2-OXOGLUTARIC_ACID                    2 OXOGLUTARIC ACID
#
#                                    Best Match Link         CAS  \
# 0  https://pubchem.ncbi.nlm.nih.gov/compound/12198    623-84-7
# 1   https://pubchem.ncbi.nlm.nih.gov/compound/2682  36653-82-4
# 2   https://pubchem.ncbi.nlm.nih.gov/compound/8221    112-92-5
# 3                                              NaN         NaN
# 4     https://pubchem.ncbi.nlm.nih.gov/compound/51    328-50-7
#
#                                       Deprecated CAS Compound/Substance
# 0  134236-23-0, 1432741-27-9, 1432741-27-9, 13423...           compound
# 1  168679-13-8, 124-29-8, 55069-45-9, 8014-51-5, ...           compound
# 2  193766-48-2, 8014-37-7, 8032-19-7, 8032-21-1, ...           compound
# 3                                                NaN            MISSING
# 4                                         27175-99-1           compound

# %%
compound_df = pharm_df[pharm_df["Compound/Substance"] == "compound"]
compound_df.describe()
# Out:
#                 Original Molecule            Parsed Molecule  \
# count                        2123                       2123
# unique                       2123                       2123
# top     1-2-PROPANEDIOL_DIACETATE  1,2 PROPANEDIOL DIACETATE
# freq                            1                          1
#
#                                       Best Match Link      CAS  \
# count                                            2123     2094
# unique                                           1828     1801
# top     https://pubchem.ncbi.nlm.nih.gov/compound/702  64-17-5
# freq                                               21       20
#
#                                            Deprecated CAS Compound/Substance
# count                                                1077               2123
# unique                                                836                  1
# top     121182-78-3, 8000-16-6, 8024-45-1, 8024-45-1, ...           compound
# freq                                                   21               2123

# %%
substance_df = pharm_df[pharm_df["Compound/Substance"] == "substance"]
substance_df.describe()
# Out:
#        Original Molecule Parsed Molecule  \
# count                586             586
# unique               586             586
# top            ABATACEPT       ABATACEPT
# freq                   1               1
#
#                                           Best Match Link          CAS  \
# count                                                 586           18
# unique                                                562           18
# top     https://pubchem.ncbi.nlm.nih.gov/substance/483...  143003-46-7
# freq                                                    5            1
#
#                             Deprecated CAS Compound/Substance
# count                                    2                586
# unique                                   2                  1
# top     71892-90-5, 79817-44-0, 87435-86-7          substance
# freq                                     1                586

# %%
missing_df = pharm_df[pharm_df["Compound/Substance"] == "MISSING"]
missing_df.describe()
# Out:
#                            Original Molecule  \
# count                                    196
# unique                                   196
# top     2-3-(2-IODOPROPYLIDENEDIOXY)PROPANOL
# freq                                       1
#
#                              Parsed Molecule  \
# count                                    196
# unique                                   196
# top     2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# freq                                       1
#
#                                  Best Match Link  CAS Deprecated CAS  \
# count                                        107    0              0
# unique                                       106    0              0
# top     https://pubmed.ncbi.nlm.nih.gov/10292123  NaN            NaN
# freq                                           2  NaN            NaN
#
#        Compound/Substance
# count                 196
# unique                  1
# top               MISSING
# freq                  196

# %% [markdown]
# ## Summary:
# -
