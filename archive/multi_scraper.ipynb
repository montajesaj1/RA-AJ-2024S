# %% [markdown]
# # 1. Libraries

# %%
import pubchempy as pcp
import csv
import re
import pandas as pd

# %%
molecules_df = pd.read_excel('../data.xlsx', sheet_name = 'in')
molecules_arr = molecules_df['molecule'].tolist()

pattern = re.compile(r'(\d)-(\d)')
pattern2 = re.compile(r'_')
pattern3 = re.compile(r'(\d)-([a-zA-Z])')

# List to store updated molecule names
updated_molecules_arr = []

for molecule in molecules_arr:
    updated_molecule = pattern.sub(r'\1,\2', molecule)
    updated_molecule = pattern2.sub(r' ', updated_molecule)
    updated_molecule = pattern3.sub(r'\1 \2', updated_molecule)
    updated_molecules_arr.append(updated_molecule)

updated_molecules_df = pd.DataFrame(updated_molecules_arr, columns=['updated_molecule'])
updated_molecules_df
# Out:
#                           updated_molecule
# 0                1,2 PROPANEDIOL DIACETATE
# 1                            1 HEXADECANOL
# 2                            1 OCTADECANOL
# 3     2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL
# 4                       2 OXOGLUTARIC ACID
# ...                                    ...
# 2900                       ZIZYPHUS JUJUBA
# 2901                       ZOLEDRONIC ACID
# 2902                          ZOLMITRIPTAN
# 2903                              ZOLPIDEM
# 2904                            ZONISAMIDE
#
# [2905 rows x 1 columns]

# %% [markdown]
# # 2. Querying the PubChem search page

# %%
def pull_item(query: str, type: str):
    '''given a compound query string, returns CAS numbers for the compound'''
    if type == 'c':
        compound = pcp.get_compounds(query, 'name')
    elif type == 's':
        compound = pcp.get_substances(query, 'name')

    aliases = compound[0].synonyms
    
    cas_pattern = re.compile(r"(\d{2,7})-(\d{2})-(\d)")
    cas_numbers = []

    for alias in aliases:
        matches = cas_pattern.findall(alias)

        for match in matches:
            cas_numbers.append('-'.join(match))

    return cas_numbers

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

def pull_item_with_type(args):
    '''Wrapper for pull_item to accept a single argument'''
    return pull_item(*args)

def generate_dict(compounds):
    '''Takes a list of compounds, retrieves all their CAS numbers using multithreading and outputs them as a dictionary'''
    compound_dict = {}
    # Tuple list for each compound and type 'c'
    tasks = [(compound, 'c') for compound in compounds]
    
    with ThreadPoolExecutor(max_workers=10) as executor:
        # Submit all tasks to the executor
        future_to_compound = {executor.submit(pull_item_with_type, task): task[0] for task in tasks}
        
        for future in as_completed(future_to_compound):
            compound = future_to_compound[future]
            try:
                compound_dict[compound] = future.result()
            except Exception as exc:
                # print(f"{compound} generated an exception: {exc}")
                compound_dict[compound] = "N/A"
                
    return compound_dict

# %%
compound_dict = generate_dict(updated_molecules_arr)

# %%
compound_dict
# Out:
# {'1,2 PROPANEDIOL DIACETATE': 'N/A',
#  '1 HEXADECANOL': 'N/A',
#  '7 KETO DEHYDRANDROSTERONE': 'N/A',
#  '1 OCTADECANOL': 'N/A',
#  '2,3-(2 IODOPROPYLIDENEDIOXY)PROPANOL': 'N/A',
#  '7 OXO-DEHYDROEPIANDROSTERONE': 'N/A',
#  '2 PROPANOL': 'N/A',
#  'ABATACEPT': 'N/A',
#  'ABCIXIMAB': 'N/A',
#  '2 PHENOXYETHANOL': [],
#  '4 AMINOBUTYRIC ACID': ['56-12-2', '20-79-1', '56-12-2', '001-19-2'],
#  '2 OXOGLUTARIC ACID': ['328-50-7',
#   '378-50-7',
#   '34410-46-3',
#   '17091-15-5',
#   '328-50-7'],
#  'ABRUS PRECATORIUS': 'N/A',
#  '8 QUINOLINOL': 'N/A',
#  'ABSORBABLE GELATIN/COLLAGEN SPONGE': 'N/A',
#  'ABALOPARATIDE': 'N/A',
#  'ABARELIX': 'N/A',
#  'ACAMPROSATE': 'N/A',
#  'ACACIA CATECHU': 'N/A',
#  'ACACIA SENEGAL': 'N/A',
#  'ACALABRUTINIB': 'N/A',
#  'ABACAVIR': 'N/A',
#  'ACARBOSE': 'N/A',
#  'ABEMACICLIB': ['1231929-97-7', '1231929-97-7'],
#  'ABIRATERONE ACETATE': ['154229-18-2', '154229-18-2', '001-02-5'],
#  'ACETOHYDROXAMIC ACID': 'N/A',
#  'ACETONE': 'N/A',
#  'ACETONE (KETONE) TESTS': 'N/A',
#  'ACESULFAME': 'N/A',
#  'ACEPROMAZINE': 'N/A',
#  'ACEMANNAN': 'N/A',
#  'ACETYL-L-CARNITINE': 'N/A',
#  'ACETIC ACID': 'N/A',
#  'ACEBUTOLOL': 'N/A',
#  'ACETAZOLAMIDE': ['59-66-5',
#   '59-66-5',
#   '001-22-9',
#   '001-26-0',
#   '124442-28-0'],
#  'ACETOHEXAMIDE': 'N/A',
#  'ACETYLCHOLINE': 'N/A',
#  'ACHILLEA MILLEFOLIUM': 'N/A',
#  'ACONITUM NAPELLUS': 'N/A',
#  'ACRIVASTINE': 'N/A',
#  'ADALIMUMAB': 'N/A',
#  'ACETYLSALICYLIC ACID': 'N/A',
#  'ADAPALENE': 'N/A',
#  'ACETYLCYSTEINE': 'N/A',
#  'ADEFOVIR DIPIVOXIL': 'N/A',
#  'ADEMETIONINE': 'N/A',
#  'ACICLOVIR': 'N/A',
#  'ACETYLSULFAFURAZOLE': ['80-74-0', '80-74-0'],
#  'ACLIDINIUM BROMIDE': 'N/A',
#  'ADENOSINE': 'N/A',
#  'ACITRETIN': 'N/A',
#  'ADIPIODONE': 'N/A',
#  'ADENOSINE TRIPHOSPHATE': 'N/A',
#  'ADRENAL CORTEX': 'N/A',
#  'AESCULUS HIPPOCASTANUM': 'N/A',
#  'AFATINIB': 'N/A',
#  'AFLIBERCEPT': 'N/A',
#  'AGARICUS CAMPESTRIS': 'N/A',
#  'ALCLOMETASONE': 'N/A',
#  'ALBUMIN': 'N/A',
#  'ALBUTREPENONACOG ALFA': 'N/A',
#  'ALCAFTADINE': 'N/A',
#  'ALDESLEUKIN': 'N/A',
#  'AGALSIDASE BETA': 'N/A',
#  'ALDIOXA': 'N/A',
#  'ALANINE': 'N/A',
#  'ALEFACEPT': 'N/A',
#  'ALEMTUZUMAB': 'N/A',
#  'ALENDRONIC ACID': 'N/A',
#  'ALBENDAZOLE': 'N/A',
#  'ALATROFLOXACIN': ['146961-76-4', '157182-32-6'],
#  'ALGINIC ACID': 'N/A',
#  'ALGLUCOSIDASE ALFA': 'N/A',
#  'ALGLUCERASE': 'N/A',
#  'ALBIGLUTIDE': ['782500-75-8'],
#  'ALECTINIB': 'N/A',
#  'ALIROCUMAB': 'N/A',
#  'ALISKIREN': 'N/A',
#  'ALITRETINOIN': 'N/A',
#  'ALFENTANIL': 'N/A',
#  'ALKYL SULFONATES': 'N/A',
#  'ALLANTOIN': 'N/A',
#  'ALLIUM CEPA': 'N/A',
#  'ALLIUM SATIVUM': 'N/A',
#  'ALFUZOSIN': 'N/A',
#  'ALLOPURINOL': 'N/A',
#  'ALMOTRIPTAN': 'N/A',
#  'ALOE AFRICANA': 'N/A',
#  'ALOE BARBADENSIS': 'N/A',
#  'ALOSETRON': 'N/A',
#  'ALPINA GALANGA': 'N/A',
#  'ALPHA CAROTENE': 'N/A',
#  'ALPHA-GALACTOSIDASE': 'N/A',
#  'ALPHA AMYLASE': 'N/A',
#  'ALPINIA OFFICINARUM': 'N/A',
#  'ALLYL ISOTHIOCYANATE': 'N/A',
#  'ALPRAZOLAM': 'N/A',
#  'ALTEPLASE': 'N/A',
#  'ALTHAEA OFFICINALIS': 'N/A',
#  'ALUMINIUM AND MAGNESIUM': 'N/A',
#  'ALOGLIPTIN': 'N/A',
#  'AMBENONIUM': 'N/A',
#  'AMBRISENTAN': 'N/A',
#  'AMBROSIA ARTEMISIFOLIA': 'N/A',
#  'AMBROSIA PSILOSTACHYA': 'N/A',
#  'ALTRETAMINE': 'N/A',
#  'AMFEPRAMONE': 'N/A',
#  'ALUMINIUM': 'N/A',
#  'ALPROSTADIL': 'N/A',
#  'ALVIMOPAN': 'N/A',
#  'AMANTADINE': 'N/A',
#  'AMFETAMINE': 'N/A',
#  'AMIKACIN': 'N/A',
#  'AMIFOSTINE': 'N/A',
#  'AMINOACIDS': 'N/A',
#  'AMCINONIDE': ['51022-69-6', '51022-69-6', '001-09-7'],
#  'AMINOCAPROIC ACID': 'N/A',
#  'AMINOACRIDINE': 'N/A',
#  'AMINOLEVULINIC ACID': 'N/A',
#  'AMILORIDE': 'N/A',
#  'AMINOGLUTETHIMIDE': 'N/A',
#  'AMINOPHYLLINE': 'N/A',
#  'AMITRIPTYLINE': 'N/A',
#  'AMINOPYRIDINE': 'N/A',
#  'AMINOSALICYLIC ACID': 'N/A',
#  'AMIODARONE': 'N/A',
#  'AMLEXANOX': 'N/A',
#  'AMLODIPINE': 'N/A',
#  'AMMONIA': 'N/A',
#  'AMMONIUM': 'N/A',
#  'AMOXAPINE': 'N/A',
#  'AMOBARBITAL': 'N/A',
#  'AMOXICILLIN': 'N/A',
#  'ANANAS COMOSUS': 'N/A',
#  'ANAKINRA': 'N/A',
#  'AMPHETAMINE': 'N/A',
#  'AMPICILLIN': 'N/A',
#  'AMPHOTERICIN B': 'N/A',
#  'ANASTROZOLE': 'N/A',
#  'AMPRENAVIR': 'N/A',
#  'ANAESTHETIC ETHER': 'N/A',
#  'AMYL NITRITE': 'N/A',
#  'ANAS BARBARIAE': 'N/A',
#  'AMRINONE': 'N/A',
#  'ANDEXANET ALFA': 'N/A',
#  'ANEMONA PULSATILLA': 'N/A',
#  'ANAGRELIDE': 'N/A',
#  'ANETHUM GRAVEOLENS': 'N/A',
#  'ANGELICA ARCHANGELICA': 'N/A',
#  'ANGELICA POLIMORPHA': 'N/A',
#  'ANGIOTENSIN 2 (HUMAN)': 'N/A',
#  'ANISTREPLASE': 'N/A',
#  'ANTACIDS': 'N/A',
#  'ANTAZOLINE': 'N/A',
#  'ANTHEMIS NOBILIS': 'N/A',
#  'ANTHOXANTHUM ODORATUM': 'N/A',
#  'ANTI-PARASITIC': 'N/A',
#  'ANTI-PSORIASIS': 'N/A',
#  'ANTI-ACNE SOAP': 'N/A',
#  'ANTIFLATULENTS': 'N/A',
#  'ANTIFUNGAL': 'N/A',
#  'ANIDULAFUNGIN': 'N/A',
#  'ANTIHISTAMINES': 'N/A',
#  'ANTIMONY': 'N/A',
#  'ANISINDIONE': ['117-37-3', '08-00-0', '117-37-3'],
#  'ANTIMONY SULPHURATED': 'N/A',
#  'ANTISEPTIC/DISINFECTANT DEODORANTS': 'N/A',
#  'ANTISEPTIC/DISINFECTANT SOLUTIONS ANDDETERGENTS': 'N/A',
#  'ANTITHROMBIN ALFA': 'N/A',
#  'APHANIZOMENON FLO AQUAE': 'N/A',
#  'ANTITHROMBIN III': 'N/A',
#  'APIS MELLIFICA': 'N/A',
#  'APALUTAMIDE': 'N/A',
#  'APIUM GRAVEOLENS': 'N/A',
#  'APIXABAN': 'N/A',
#  'APLIGRAF': 'N/A',
#  'APOAEQUORIN': 'N/A',
#  'APPLE VINEGAR': 'N/A',
#  'ARACHIS HYPOGAEA': 'N/A',
#  'ARABINOGALACTAN': 'N/A',
#  'ARALIA ELATA': 'N/A',
#  'ARALIA RACEMOSA': 'N/A',
#  'ARANEUS DIADEMATUS': 'N/A',
#  'APOMORPHINE': ['58-00-4', '58-00-4', '58-00-4', '001-01-3', '311-20-6'],
#  'APRACLONIDINE': 'N/A',
#  'ARCTIUM LAPPA': 'N/A',
#  'ARDEPARIN SODIUM': 'N/A',
#  'ARCTOSTAPHYLOS UVA-URSI': 'N/A',
#  'APREPITANT': 'N/A',
#  'ARFORMOTEROL': 'N/A',
#  'APREMILAST': 'N/A',
#  'ARGANIA SPINOSA': 'N/A',
#  'ARNICA MONTANA': 'N/A',
#  'ARTEMISIA ABSINTHIUM': 'N/A',
#  'ARGININE': 'N/A',
#  'ARGATROBAN': 'N/A',
#  'ARTICAINE': 'N/A',
#  'APROTININ': 'N/A',
#  'ARMODAFINIL': 'N/A',
#  'ARTIFICIAL SWEETENERS': 'N/A',
#  'ARIPIPRAZOLE LAUROXIL': 'N/A',
#  'ARSENIC': ['7440-38-2'],
#  'ASCOPHYLLUM NODOSUM': 'N/A',
#  'ARTEMETHER': 'N/A',
#  'ASCORBIC ACID': 'N/A',
#  'ASFOTASE ALFA': 'N/A',
#  'ASPALANTHUS LINEARIS': 'N/A',
#  'ASPARAGUS RACEMOSUS': 'N/A',
#  'ARIPIPRAZOLE': ['129722-12-9',
#   '129722-12-9',
#   '1026778-41-5',
#   '129722-12-9',
#   '001-06-6',
#   '24-29-3'],
#  'ASTEMIZOLE': 'N/A',
#  'ATAZANAVIR': 'N/A',
#  'ASTRAGALUS': 'N/A',
#  'ATENOLOL': 'N/A',
#  'ASPARAGINASE': 'N/A',
#  'ATEZOLIZUMAB': 'N/A',
#  'ASPARTAME': 'N/A',
#  'ATOMOXETINE': 'N/A',
#  'ASPARTIC ACID': 'N/A',
#  'ASTAXANTHIN': 'N/A',
#  'ATORVASTATIN': 'N/A',
#  'ASENAPINE': 'N/A',
#  'ATOVAQUONE': 'N/A',
#  'ATRACURIUM BESILATE': 'N/A',
#  'ATROPA BELLADONNA': 'N/A',
#  'ATROPINE': 'N/A',
#  'ATTAPULGITE': 'N/A',
#  'AVENA SATIVA': 'N/A',
#  'AVIBACTAM': 'N/A',
#  'AVELUMAB': 'N/A',
#  'AVOBENZONE': 'N/A',
#  'AURANTIIN': 'N/A',
#  'AXITINIB': 'N/A',
#  'AZADIRACHTA INDICA': 'N/A',
#  'AZATADINE': 'N/A',
#  'AURANOFIN': 'N/A',
#  'AUROTHIOMALIC ACID': ['33796-26-8'],
#  'AUROTHIOGLUCOSE': 'N/A',
#  'AZELAIC ACID': 'N/A',
#  'AZATHIOPRINE': 'N/A',
#  'AZELASTINE': 'N/A',
#  'B>-SITOSTEROL': 'N/A',
#  'AVATROMBOPAG': ['570406-98-3', '570406-98-3'],
#  'AVANAFIL': ['330784-47-9', '001-01-4'],
#  'BABY CREAMS': 'N/A',
#  'BABY POWDER (TALC)': 'N/A',
#  'BABY LOTION': 'N/A',
#  'AZACITIDINE': ['320-67-2',
#   '320-67-2',
#   '001-02-1',
#   '001-27-8',
#   '1401238-97-8'],
#  'BABY SOAPS': 'N/A',
#  'BABY SHAMPOOS': 'N/A',
#  'BACILLUS COAGULANS': 'N/A',
#  'AZITHROMYCIN': 'N/A',
#  'BACITRACIN': 'N/A',
#  'BACLOFEN': 'N/A',
#  'BACOPA MONIERI': 'N/A',
#  'BALOXAVIR MARBOXIL': 'N/A',
#  'BAMBUSA': 'N/A',
#  'AZILSARTAN MEDOXOMIL': ['863031-21-4'],
#  'BANDAGES': 'N/A',
#  'AZTREONAM': ['78110-38-0', '149496-40-2', '80951-91-3', '001-03-0'],
#  'BAROSMA BETULINA': 'N/A',
#  'BASILIXIMAB': 'N/A',
#  'BECAPLERMIN': 'N/A',
#  'BAZEDOXIFENE': 'N/A',
#  'BATH OIL': 'N/A',
#  'BECLOMETASONE': 'N/A',
#  'BELATACEPT': 'N/A',
#  'BARIUM': 'N/A',
#  'BALSALAZIDE': 'N/A',
#  'BARBITAL': 'N/A',
#  'BELINOSTAT': 'N/A',
#  'BELIMUMAB': 'N/A',
#  'BARICITINIB': 'N/A',
#  'BELLIS': 'N/A',
#  'BENDAMUSTINE': 'N/A',
#  'BENAZEPRIL': 'N/A',
#  'BENDROFLUMETHIAZIDE': 'N/A',
#  'BEDAQUILINE': 'N/A',
#  'BENRALIZUMAB': 'N/A',
#  'BENZALKONIUM CHLORIDE': 'N/A',
#  'BENZOIC ACID': 'N/A',
#  'BENTONITE': 'N/A',
#  'BENZOYL PEROXIDE': 'N/A',
#  'BENTOQUATAM': 'N/A',
#  'BENZATROPINE': 'N/A',
#  'BENZOCAINE': 'N/A',
#  'BENZOPHENONE': 'N/A',
#  'BENZYL ALCOHOL': 'N/A',
#  'BENZETHONIUM CHLORIDE': 'N/A',
#  'BENZOXIQUINE': 'N/A',
#  'BENZONATATE': 'N/A',
#  'BENZYL BENZOATE': 'N/A',
#  'BEPOTASTINE': 'N/A',
#  'BEPRIDIL': 'N/A',
#  'BERACTANT': 'N/A',
#  'BERBERIS VULGARIS': 'N/A',
#  'BENZPHETAMINE': ['156-08-1', '156-08-1'],
#  'BETA VULGARIS': 'N/A',
#  'BEVACIZUMAB': 'N/A',
#  'BETACAROTENE': 'N/A',
#  'BETAHISTINE': 'N/A',
#  'BEXAROTENE': 'N/A',
#  'BESIFLOXACIN': 'N/A',
#  'BETHANECHOL': 'N/A',
#  'BETAMETHASONE': 'N/A',
#  'BETAXOLOL': 'N/A',
#  'BETAINE': 'N/A',
#  'BETRIXABAN': 'N/A',
#  'BEZLOTOXUMAB': 'N/A',
#  'BICALUTAMIDE': 'N/A',
#  'BICTEGRAVIR': 'N/A',
#  'BIFIDOBACTERIUM ANIMALIS': 'N/A',
#  'BIFIDOBACTERIUM BIFIDUS': 'N/A',
#  'BIFIDOBACTERIUM BREVE': 'N/A',
#  'BIFIDOBACTERIUM INFANTIS': 'N/A',
#  'BILE': 'N/A',
#  'BIFIDOBACTERIUM LONGUM': 'N/A',
#  'BILIARY ACIDS': 'N/A',
#  'BILIRUBIN TESTS': 'N/A',
#  'BIOFLAVONOIDS': 'N/A',
#  'BISACODYL': 'N/A',
#  'BISOPROLOL': 'N/A',
#  'BITOLTEROL': 'N/A',
#  'BIVALIRUDIN': 'N/A',
#  'BLEOMYCIN': 'N/A',
#  'BLINATUMOMAB': 'N/A',
#  'BIOTIN': 'N/A',
#  'BIMATOPROST': 'N/A',
#  'BLOOD COAGULATION TEST': 'N/A',
#  'BIPERIDEN': 'N/A',
#  'BISMUTH': 'N/A',
#  'BLOOD PLASMA': 'N/A',
#  'BOCEPREVIR': 'N/A',
#  'BINIMETINIB': 'N/A',
#  'BORAGO OFFICINALIS': 'N/A',
#  'BOSWELLIA SERRATIA': 'N/A',
#  'BRAN': 'N/A',
#  'BRASSICA NAPUS': 'N/A',
#  'BRASSICA CAMPESTRIS': 'N/A',
#  'BRASSICA NIGRA': 'N/A',
#  'BORON': 'N/A',
#  'BREATH FRESHNERS': 'N/A',
#  'BRENTUXIMAB VEDOTIN': 'N/A',
#  'BORIC ACID': ['10043-35-3',
#   '11113-50-1',
#   '10043-35-3',
#   '1332-77-0',
#   '11113-50-1'],
#  'BRETYLIUM': 'N/A',
#  'BREXPIPRAZOLE': 'N/A',
#  'BRIGATINIB': 'N/A',
#  'BOSENTAN': 'N/A',
#  'BRILLIANT GREEN': 'N/A',
#  'BOSUTINIB': 'N/A',
#  'BORTEZOMIB': 'N/A',
#  'BROMINE': 'N/A',
#  'BROMELAINS': 'N/A',
#  'BRODALUMAB': 'N/A',
#  'BROMPHENIRAMINE': 'N/A',
#  'BRONOPOL': 'N/A',
#  'BUDESONIDE': 'N/A',
#  'BRYONIA ALBA': 'N/A',
#  'BUMETANIDE': 'N/A',
#  'BROMAZINE': 'N/A',
#  'BROMOCRIPTINE': 'N/A',
#  'BROMFENAC': 'N/A',
#  'BRIMONIDINE': ['59803-98-4', '59803-98-4', '001-10-0'],
#  'BRINZOLAMIDE': ['138890-62-7', '138890-50-3', '138890-62-7', '001-03-3'],
#  'BUPROPION': 'N/A',
#  'BRIVARACETAM': 'N/A',
#  'BUROSUMAB': 'N/A',
#  'BUPIVACAINE': 'N/A',
#  'BUPRENORPHINE': 'N/A',
#  'BUTYLATED HYDROXYANISOLE': 'N/A',
#  'BUTYLCAINE': 'N/A',
#  'BUTYLHYDROXYTOLUOL': 'N/A',
#  'BUSULFAN': 'N/A',
#  'BUTYLPARABEN': 'N/A',
#  'BUTYROSPERMUM PARKII': 'N/A',
#  'C1 INHIBITOR (HUMAN)': 'N/A',
#  'BUTOCONAZOLE': 'N/A',
#  'BUTENAFINE': 'N/A',
#  'BUTORPHANOL': 'N/A',
#  'BUTALAMINE': ['22131-35-7'],
#  'BUTALBITAL': ['77-26-9', '001-01-6'],
#  'CABAZITAXEL': 'N/A',
#  'BUSPIRONE': ['36505-84-7',
#   '116753-41-4',
#   '36505-84-7',
#   '33386-08-2',
#   '001-01-5',
#   '003-03-7',
#   '003-14-4'],
#  'CABERGOLINE': 'N/A',
#  'CABOZANTINIB': 'N/A',
#  'CACAO BUTTER': 'N/A',
#  'CADEXOMER IODINE': 'N/A',
#  'CADE OIL': 'N/A',
#  'CAJUPUT': 'N/A',
#  'CALASPARGASE PEGOL': 'N/A',
#  'CALCITONIN (SALMON)': 'N/A',
#  'CALCIUM': 'N/A',
#  'CALCIUM FOLINATE': 'N/A',
#  'CAFFEINE': 'N/A',
#  'CALCIUM LEVOFOLINATE': 'N/A',
#  'CALCIUM MEFOLINATE': 'N/A',
#  'CALAMINE': 'N/A',
#  'CALENDULA OFFICINALIS': 'N/A',
#  'CALFACTANT': 'N/A',
#  'CAMPESTEROL': 'N/A',
#  'CAMELLIA SINENSIS': 'N/A',
#  'CALCIPOTRIOL': 'N/A',
#  'CALCIFEDIOL': 'N/A',
#  'CALCITRIOL': 'N/A',
#  'CAMPHOR': 'N/A',
#  'CANAGLIFLOZIN': 'N/A',
#  'CANAKINUMAB': 'N/A',
#  'CANDIDA ALBICANS': 'N/A',
#  'CANDIDA TESTS': 'N/A',
#  'CANTHARIDES': 'N/A',
#  'CANTHARIDIN': 'N/A',
#  'CAPREOMYCIN': 'N/A',
#  'CAPLACIZUMAB': 'N/A',
#  'CAPROMAB': 'N/A',
#  'CANDESARTAN CILEXETIL': 'N/A',
#  'CAPSICUM': 'N/A',
#  'CAPSICUM OLEORESIN': 'N/A',
#  'CAPECITABINE': 'N/A',
#  'CAPTOPRIL': 'N/A',
#  'CARALLUMA FIMBRIATA': 'N/A',
#  'CANGRELOR': 'N/A',
#  'CANNABIDIOL': 'N/A',
#  'CARAMIPHEN': 'N/A',
#  'CARBACHOL': 'N/A',
#  'CARBAMAZEPINE': 'N/A',
#  'CARAPA GUIANENSIS': 'N/A',
#  'CARBENICILLIN': 'N/A',
#  'CARBINOXAMINE': 'N/A',
#  'CARBITOL': 'N/A',
#  'CARBIDOPA': 'N/A',
#  'CARBOHYDRATES': 'N/A',
#  'CARDIOSPERMUM': 'N/A',
#  'CARBOCISTEINE': 'N/A',
#  'CAPSAICIN': ['404-86-4',
#   '7553-53-9',
#   '1217899-52-9',
#   '404-86-4',
#   '404-86-4',
#   '001-01-1',
#   '001-06-6'],
#  'CARGLUMIC ACID': 'N/A',
#  'CARBONIC ACID': 'N/A',
#  'CARBONYL IRON': 'N/A',
#  'CARBOMER': 'N/A',
#  'CARBOPLATIN': 'N/A',
#  'CARICA PAPAYA': 'N/A',
#  'CARINDACILLIN': 'N/A',
#  'CARIPRAZINE': 'N/A',
#  'CARISOPRODOL': 'N/A',
#  'CARMELLOSE': 'N/A',
#  'CARMUSTINE': 'N/A',
#  'CARBOPROST': 'N/A',
#  'CARFILZOMIB': 'N/A',
#  'CARNAUBA WAX': 'N/A',
#  'CARNOSINE': 'N/A',
#  'CAROTEN': 'N/A',
#  'CAROTENOIDS (UNSPECIFIED)': 'N/A',
#  'CARTHAMUS TINCTORIUS': 'N/A',
#  'CARUM PETROSELINUM': 'N/A',
#  'CASTOR FIBER': 'N/A',
#  'CATHETERS': 'N/A',
#  'CATRIDECACOG': 'N/A',
#  'CEDAR WOOD OIL': 'N/A',
#  'CEDRUS ATLANTICA': 'N/A',
#  'CEFACLOR': 'N/A',
#  'CASANTHRANOL': 'N/A',
#  'CEFADROXIL': 'N/A',
#  'CEFALEXIN': 'N/A',
#  'CARTEOLOL': 'N/A',
#  'CASEIN': 'N/A',
#  'CARVEDILOL': 'N/A',
#  'CEFAMANDOLE': 'N/A',
#  'CEFAPIRIN': 'N/A',
#  'CASPOFUNGIN': ['162808-62-0'],
#  'CEFONICID': 'N/A',
#  'CEFAZOLIN': 'N/A',
#  'CEFMETAZOLE': 'N/A',
#  'CEFOPERAZONE': 'N/A',
#  'CEFOTETAN': 'N/A',
#  'CEFEPIME': 'N/A',
#  'CEFOTAXIME': 'N/A',
#  'CEFDINIR': ['91832-40-5', '91832-40-5', '001-05-6'],
#  'CEFDITOREN PIVOXIL': 'N/A',
#  'CEFIXIME': 'N/A',
#  'CEFRADINE': 'N/A',
#  'CEFPROZIL': ['92665-29-7', '92676-86-3'],
#  'CEFTIZOXIME': 'N/A',
#  'CEFTRIAXONE': 'N/A',
#  'CEFTOLOZANE': 'N/A',
#  'CEFOXITIN': 'N/A',
#  'CEFPODOXIME PROXETIL': ['87239-81-4', '947692-13-9', '87239-81-4'],
#  'CEFUROXIME': 'N/A',
#  'CEFTIBUTEN': 'N/A',
#  'CEFUROXIME AXETIL': 'N/A',
#  'CEFTAZIDIME': 'N/A',
#  'CELLULASE': 'N/A',
#  'CELECOXIB': 'N/A',
#  'CEMIPLIMAB': 'N/A',
#  'CENTELLA ASIATICA': 'N/A',
#  'CEPHAELIS IPECACUANHA': 'N/A',
#  'CEFTAROLINE FOSAMIL': ['229016-73-3'],
#  'CERIUM': 'N/A',
#  'CERAMIDE': 'N/A',
#  'CERLIPONASE ALFA': 'N/A',
#  'CERTOLIZUMAB PEGOL': 'N/A',
#  'CELLULOSE': ['9004-34-6'],
#  'CETIRIZINE': 'N/A',
#  'CETRIMIDE': 'N/A',
#  'CETRORELIX': 'N/A',
#  'CETUXIMAB': 'N/A',
#  'CEVIMELINE': 'N/A',
#  'CETYLPYRIDINIUM': 'N/A',
#  'CHARCOAL': 'N/A',
#  'CERITINIB': 'N/A',
#  'CETALKONIUM': 'N/A',
#  'CERIVASTATIN': 'N/A',
#  'CHERRY': 'N/A',
#  'CHELIDONIUM MAJUS': 'N/A',
#  'CHLORELLA': 'N/A',
#  'CHLORMETHINE': 'N/A',
#  'CHLORAMBUCIL': 'N/A',
#  'CHLOROBUTANOL': 'N/A',
#  'CHLORAL HYDRATE': 'N/A',
#  'CHLORAMPHENICOL': 'N/A',
#  'CHLOROPHYLLIN COPPER COMPLEX': 'N/A',
#  'CHLOROFORM': 'N/A',
#  'CHLOROETHANE': 'N/A',
#  'CHLOROPHYLL': 'N/A',
#  'CHLORINE': 'N/A',
#  'CHLORCYCLIZINE': 'N/A',
#  'CHLORDIAZEPOXIDE': 'N/A',
#  'CHLORHEXIDINE': 'N/A',
#  'CHLORPHENESIN': 'N/A',
#  'CHLOROQUINE': 'N/A',
#  'CHLOROPROCAINE': 'N/A',
#  'CHLORTALIDONE': 'N/A',
#  'CHLORPROMAZINE': 'N/A',
#  'CHLOROTHIAZIDE': 'N/A',
#  'CHLOROXYLENOL': 'N/A',
#  'CHLOROXINE': 'N/A',
#  'CHLOROTHYMOL': 'N/A',
#  'CHLORPHENAMINE': ['132-22-9', '25523-97-1', '050-03-0', '050-08-9'],
#  'CHOLESTEROL TESTS': 'N/A',
#  'CHOLINE THEOPHYLLINATE': 'N/A',
#  'CHONDROCYTE': 'N/A',
#  'CHONDRUS CRISPUS': 'N/A',
#  'CHLORPROPAMIDE': ['94-20-2', '94-20-2', '001-05-6', '001-15-5'],
#  'CHORIOGONADOTROPIN ALFA': 'N/A',
#  'CHOLESTEROL': 'N/A',
#  'CHOLINE': 'N/A',
#  'CHLORZOXAZONE': ['95-25-0', '95-25-0', '001-05-7', '001-08-1'],
#  'CHORIONIC GONADOTROPHIN': 'N/A',
#  'CHROMIUM': 'N/A',
#  'CHRYSIN': 'N/A',
#  'CHONDROITINSULFURIC ACID': 'N/A',
#  'CICLESONIDE': 'N/A',
#  'CICLOPIROX': 'N/A',
#  'CHOLINE FENOFIBRATE': ['856676-23-8'],
#  'CIMICIFUGA RACEMOSA': 'N/A',
#  'CINCHOCAINE': 'N/A',
#  'CINEOLE': 'N/A',
#  'CINERARIA': 'N/A',
#  'CICLOSPORIN': 'N/A',
#  'CIDOFOVIR': ['113852-37-2', '113852-37-2'],
#  'CINNAMEDRINE': 'N/A',
#  'CILASTATIN': ['82009-34-5', '81129-83-1'],
#  'CILOSTAZOL': 'N/A',
#  'CINNAMOMUM CAMPHORA': 'N/A',
#  'CINNAMOMUM CASSIA': 'N/A',
#  'CINACALCET': 'N/A',
#  'CINNAMOMUM LOUREIRII': 'N/A',
#  'CINOXACIN': 'N/A',
#  'CINNAMOMUM ZEYLANICUM': 'N/A',
#  'CINOXATE': 'N/A',
#  'CIMETIDINE': 'N/A',
#  'CIPROFLOXACIN': 'N/A',
#  'CISSUS QUADRANGULARIS': 'N/A',
#  'CITICOLINE': 'N/A',
#  'CITRULLINE': 'N/A',
#  'CITRONELLA OIL': 'N/A',
#  'CITRULLUS COLOCYNTHIS': 'N/A',
#  'CITRUS AURANTIUM': 'N/A',
#  'CISATRACURIUM BESILATE': 'N/A',
#  'CITRUS BERGAMIA': 'N/A',
#  'CITRIC ACID': 'N/A',
#  'CISPLATIN': ['14913-33-8'],
#  'CITRUS LIMONUM': 'N/A',
#  'CITRUS DECUMANA': 'N/A',
#  'CITRUS PARADISI': 'N/A',
#  'CITALOPRAM': 'N/A',
#  'CISAPRIDE': 'N/A',
#  'CITRUS SINENSIS': 'N/A',
#  'CLADRIBINE': 'N/A',
#  'CLARITHROMYCIN': 'N/A',
#  'CLAVICEPS PURPUREA': 'N/A',
#  'CLAVULANIC ACID': 'N/A',
#  'CLAY': 'N/A',
#  'CLEMASTINE': 'N/A',
#  'CLEVIDIPINE': 'N/A',
#  'CLIDINIUM': 'N/A',
#  'CLINDAMYCIN': 'N/A',
#  'CLIOQUINOL': 'N/A',
#  'CLOBAZAM': 'N/A',
#  'CLOFAZIMINE': 'N/A',
#  'CLOMIFENE': 'N/A',
#  'CLOMIPRAMINE': 'N/A',
#  'CLONAZEPAM': 'N/A',
#  'CLONIDINE': 'N/A',
#  'CLOPIDOGREL': 'N/A',
#  'CLOFEDANOL': 'N/A',
#  'CLORAZEPIC ACID': 'N/A',
#  'CLOCORTOLONE': 'N/A',
#  'CLOBETASOL': 'N/A',
#  'CLOFIBRATE': 'N/A',
#  'CLOSTRIDIUM BOTULINUM TOXIN TYPE A': 'N/A',
#  'CLOSTRIDIUM BOTULINUM TOXIN TYPE B': 'N/A',
#  'CLOTRIMAZOLE': 'N/A',
#  'CLOFARABINE': 'N/A',
#  'CLOXACILLIN': 'N/A',
#  'CLOXIQUINE': 'N/A',
#  'CLOZAPINE': 'N/A',
#  'CNIDIUM': 'N/A',
#  'COAL TAR': 'N/A',
#  'COBALT': 'N/A',
#  'COBAMAMIDE': 'N/A',
#  'COBICISTAT': 'N/A',
#  'COBIMETINIB': 'N/A',
#  'COCAINE': 'N/A',
#  'COCAMIDOPROPYL BETAINAMIDE MONOETHANOLAMINE': 'N/A',
#  'COCARBOXYLASE': 'N/A',
#  'COCCULUS': 'N/A',
#  'COCOS NUCIFERA': 'N/A',
#  'CODEINE': 'N/A',
#  'CODONOPSIS': 'N/A',
#  'COFFEA': 'N/A',
#  'COD LIVER OIL': 'N/A',
#  'COIX LACHRYMA-JOBI': 'N/A',
#  'COLA ACUMINATA': 'N/A',
#  'COLA NITIDA': 'N/A',
#  'COLCHICINE': 'N/A',
#  'COLECALCIFEROL': 'N/A',
#  'COLESEVELAM': 'N/A',
#  'COLESTIPOL': 'N/A',
#  'COLESTYRAMINE': 'N/A',
#  'COLEUS FORSKOHLII': 'N/A',
#  'COLFOSCERIL PALMITATE': 'N/A',
#  'COLISTIN': 'N/A',
#  'COLLAGEN': 'N/A',
#  'COLLAGENASE': 'N/A',
#  'COLLAGENASE CLOSTRIDIUM HISTOLYTICUM': 'N/A',
#  'COLLODIONS': 'N/A',
#  'COLOSTRUM': 'N/A',
#  'COMMIPHORA MOLMOL': 'N/A',
#  'COMMIPHORA WIGHTII': 'N/A',
#  'COMPOSITION UNKNOWN': 'N/A',
#  'CONDOMS': 'N/A',
#  'CONESTAT ALFA': 'N/A',
#  'CONIUM MACULATUM': 'N/A',
#  'COOLING PAD': 'N/A',
#  'CONIVAPTAN': 'N/A',
#  'CONTRACEPTIVE DEVICES': 'N/A',
#  'COPANLISIB': 'N/A',
#  'COPPER': 'N/A',
#  'CORBADRINE': 'N/A',
#  'CORDIA SALICIFOLIA': 'N/A',
#  'CORIANDRUM SATIVUM': 'N/A',
#  'CORDYCEPS SINENSIS SACC': 'N/A',
#  'CORTICORELIN': 'N/A',
#  'CORTISONE': 'N/A',
#  'CORYLUS AVELLANA': 'N/A',
#  'CORTICOTROPIN': 'N/A',
#  'CRATAEGUS LAEVIGATA': 'N/A',
#  'COUGH AND COLD PREPARATIONS': 'N/A',
#  'CORYNEBACTERIUM DIPHTHERIAE TOXIN': 'N/A',
#  'CREATININE': 'N/A',
#  'CREOSOTE': 'N/A',
#  'CREATINE': 'N/A',
#  'CREAMS (BASIS)': 'N/A',
#  'CRIZOTINIB': 'N/A',
#  'CROFELEMER': 'N/A',
#  'CROTALUS HORRIDUS': 'N/A',
#  'CROMOGLICIC ACID': 'N/A',
#  'CRYOFLUORANE': 'N/A',
#  'CRYPTHECODINIUM COHNII': 'N/A',
#  'CRISABOROLE': 'N/A',
#  'CROTAMITON': 'N/A',
#  'CUCUMIS SATIVUS': 'N/A',
#  'CUCURBITA PEPO': 'N/A',
#  'CUPRESSUS SEMPERVIRENS': 'N/A',
#  'CRYPTOXANTHIN': 'N/A',
#  'CRYSTAL VIOLET': 'N/A',
#  'CYANOCOBALAMIN': 'N/A',
#  'CURCUMA LONGA': 'N/A',
#  'CURCUMIN': 'N/A',
#  'CYCLOSERINE': 'N/A',
#  'CYCLANDELATE': 'N/A',
#  'CYCLIZINE': 'N/A',
#  'CYCLOMETHICONE': 'N/A',
#  'CYCLOBENZAPRINE': 'N/A',
#  'CYSTEINE': 'N/A',
#  'CYTARABINE': 'N/A',
#  'CYCLOPENTASILOXANE': 'N/A',
#  'D-LACTIC ACID': 'N/A',
#  'CYCLOPENTOLATE': 'N/A',
#  'CYCLOPHOSPHAMIDE': 'N/A',
#  'DABIGATRAN ETEXILATE': 'N/A',
#  'CYNARA SCOLYMUS': 'N/A',
#  'CYPROHEPTADINE': 'N/A',
#  'CYSTINE': 'N/A',
#  'DABRAFENIB': 'N/A',
#  'DACLIZUMAB': 'N/A',
#  'CYSTOSEIRA CANARIENSIS': 'N/A',
#  'DACTINOMYCIN': 'N/A',
#  'DACTYLIS GLOMERATA': 'N/A',
#  'DALFOPRISTIN': 'N/A',
#  'DACARBAZINE': 'N/A',
#  'DACLATASVIR': 'N/A',
#  'DACOMITINIB': 'N/A',
#  'DANAZOL': 'N/A',
#  'DACTYLOPIUS COCCUS': 'N/A',
#  'DALBAVANCIN': 'N/A',
#  'DALTEPARIN SODIUM': 'N/A',
#  'DAMOCTOCOG ALFA PEGOL': 'N/A',
#  'DANAPAROID': 'N/A',
#  'DAPIPRAZOLE': 'N/A',
#  'DANTROLENE': 'N/A',
#  'DARATUMUMAB': 'N/A',
#  'DAPAGLIFLOZIN': 'N/A',
#  'DAPTOMYCIN': 'N/A',
#  'DAPSONE': 'N/A',
#  'DARBEPOETIN ALFA': 'N/A',
#  'DANTRON': 'N/A',
#  'DARIFENACIN': 'N/A',
#  'DARUNAVIR': 'N/A',
#  'DASABUVIR': 'N/A',
#  'DASATINIB': 'N/A',
#  'DAUCUS CAROTA': 'N/A',
#  'DECONGESTANT RUBS': 'N/A',
#  'DECITABINE': 'N/A',
#  'DAUNORUBICIN': 'N/A',
#  'DEANOL': 'N/A',
#  'DECANOIC ACID': 'N/A',
#  'DEFERASIROX': 'N/A',
#  'DEFERIPRONE': 'N/A',
#  'DEFEROXAMINE': 'N/A',
#  'DEFIBROTIDE': 'N/A',
#  'DEFLAZACORT': 'N/A',
#  'DEGARELIX': 'N/A',
#  'DELAFLOXACIN': 'N/A',
#  'DEMECARIUM': 'N/A',
#  'DELAVIRDINE': 'N/A',
#  'DEMECLOCYCLINE': 'N/A',
#  'DENILEUKIN DIFTITOX': 'N/A',
#  'DENOSUMAB': 'N/A',
#  'DENTAL FLOSS': 'N/A',
#  'DENTURE POWDER': 'N/A',
#  'DEOXYCHOLIC ACID': 'N/A',
#  'DERMATOPHAGOIDES PTERONYSSINUS': 'N/A',
#  'DERMATOPHAGOIDES FARINAE': 'N/A',
#  'DERMAGRAFT-TC': 'N/A',
#  'DESERPIDINE': 'N/A',
#  'DESFLURANE': 'N/A',
#  'DEOXYRIBONUCLEASE- NATURAL': 'N/A',
#  'DESIPRAMINE': 'N/A',
#  'DESIRUDIN': 'N/A',
#  'DESLORATADINE': 'N/A',
#  'DESMOPRESSIN': 'N/A',
#  'DESVENLAFAXINE': 'N/A',
#  'DESOXIMETASONE': 'N/A',
#  'DEUTETRABENAZINE': 'N/A',
#  'DESOGESTREL': 'N/A',
#  'DESONIDE': 'N/A',
#  'DEXAMETHASONE': 'N/A',
#  'DEXAMFETAMINE': 'N/A',
#  'DEXBROMPHENIRAMINE': 'N/A',
#  'DEXLANSOPRAZOLE': 'N/A',
#  'DEXCHLORPHENIRAMINE': 'N/A',
#  'DEXRAZOXANE': 'N/A',
#  'DEXTRANOMER': 'N/A',
#  'DEXMEDETOMIDINE': 'N/A',
#  'DEXTRAN': 'N/A',
#  'DEXPANTHENOL': 'N/A',
#  'DEXMETHYLPHENIDATE': 'N/A',
#  'DEXTRIN': 'N/A',
#  'DIASTASE': 'N/A',
#  'DIAZOXIDE': 'N/A',
#  'DICHLORALPHENAZONE': 'N/A',
#  'DIAGNOSTIC COLON IMAGING AGENT': 'N/A',
#  'DEXTROMETHORPHAN': 'N/A',
#  'DEXTROPROPOXYPHENE': 'N/A',
#  'DIAZOLIDINYL UREA': 'N/A',
#  'DEXTROTHYROXINE': 'N/A',
#  'DIAZEPAM': 'N/A',
#  'DIATRIZOIC ACID': 'N/A',
#  'DICLOXACILLIN': 'N/A',
#  'DIENESTROL': 'N/A',
#  'DICOUMAROL': 'N/A',
#  'DICLOFENAMIDE': 'N/A',
#  'DICLOFENAC': 'N/A',
#  'DICHLORODIFLUORO-METHANE': 'N/A',
#  'DICHLOROACETIC ACID': 'N/A',
#  'DIDANOSINE': 'N/A',
#  'DICYCLOVERINE': 'N/A',
#  'DIENOGEST': 'N/A',
#  'DIETHYLSTILBESTROL': 'N/A',
#  'DIETHYLTOLUAMIDE': 'N/A',
#  'DIFENOXIN': 'N/A',
#  'DIFLUNISAL': 'N/A',
#  'DIGITOXIN': 'N/A',
#  'DIGOXIN SPECIFIC ANTIBODY FRAGMENTS': 'N/A',
#  'DIGOXIN': 'N/A',
#  'DIHYDROCODEINE': 'N/A',
#  'DIFLORASONE': 'N/A',
#  'DIFLUPREDNATE': 'N/A',
#  'DIHYDROERGOTAMINE': 'N/A',
#  'DIHYDROERGOTOXINE': 'N/A',
#  'DIHYDROTACHYSTEROL': 'N/A',
#  'DIHYDROXYACETONE': 'N/A',
#  'DIMETHYLGLYCINE': 'N/A',
#  'DIIODOHYDROXYQUINOLINE': 'N/A',
#  'DIHYDROXYALUMINIUM': 'N/A',
#  'DIMENHYDRINATE': 'N/A',
#  'DILTIAZEM': 'N/A',
#  'DIMETHYL FUMARATE': 'N/A',
#  'DIMETHYL SULFONE': 'N/A',
#  'DIMETHYL SULFOXIDE': 'N/A',
#  'DIMETICONE': 'N/A',
#  'DINUTUXIMAB': 'N/A',
#  'DIOSCOREA VILLOSA': 'N/A',
#  'DIOSMIN': 'N/A',
#  'DINOPROSTONE': 'N/A',
#  'DIPHENHYDRAMINE': 'N/A',
#  'DIPHENOXYLATE': 'N/A',
#  'DIOXYBENZONE': 'N/A',
#  'DIPHENYLPYRALINE': 'N/A',
#  'DIPIVEFRINE': 'N/A',
#  'DIPROPHYLLINE': 'N/A',
#  'DIPROPYLENEGLYCOL': 'N/A',
#  'DIRITHROMYCIN': 'N/A',
#  'DISOPYRAMIDE': 'N/A',
#  'DIPYRIDAMOLE': 'N/A',
#  'DISPOSABLE MEDICAL DEVICES': 'N/A',
#  'DISINFECTANT SOLUTIONS / DETERGENTS': 'N/A',
#  'DISULFIRAM': 'N/A',
#  'DIURETICS AND URINARY PREPARATION': 'N/A',
#  'DITHRANOL': 'N/A',
#  'DL-LACTIC ACID': 'N/A',
#  'DOCONEXENT': 'N/A',
#  'DOCOSAPENTAENOIC ACID': 'N/A',
#  'DOCOSAHEXANOIC ACID': 'N/A',
#  'DOCETAXEL': 'N/A',
#  'DOCOSANOL': 'N/A',
#  'DOBUTAMINE': 'N/A',
#  'DOCUSATE': 'N/A',
#  'DODECYL SULFOACETIC ACID': 'N/A',
#  'DOFETILIDE': 'N/A',
#  'DOLASETRON': 'N/A',
#  'DOLOMITE': 'N/A',
#  'DOLUTEGRAVIR': 'N/A',
#  'DOMIPHEN': 'N/A',
#  'DOMPERIDONE': 'N/A',
#  'DONEPEZIL': 'N/A',
#  'DOPAMINE': 'N/A',
#  'DORAVIRINE': 'N/A',
#  'DORIPENEM': 'N/A',
#  'DORNASE ALFA': 'N/A',
#  'DORZOLAMIDE': 'N/A',
#  'DOXACURIUM CHLORIDE': 'N/A',
#  'DOXAPRAM': 'N/A',
#  'DOXAZOSIN': 'N/A',
#  'DOXEPIN': 'N/A',
#  'DOXERCALCIFEROL': 'N/A',
#  'DOXORUBICIN': 'N/A',
#  'DOXYCYCLINE': 'N/A',
#  'DOXYLAMINE': 'N/A',
#  'DRAKEOL-15': 'N/A',
#  'DRESSING STRIPS': 'N/A',
#  'DRAKEOL-35': 'N/A',
#  'DRONABINOL': 'N/A',
#  'DROMAIUS NOVAEHOLLANDIAE': 'N/A',
#  'DRONEDARONE': 'N/A',
#  'DROPERIDOL': 'N/A',
#  'DROSPIRENONE': 'N/A',
#  'DROSERA ROTUNDIFOLIA': 'N/A',
#  'DROXIDOPA': 'N/A',
#  'DROTRECOGIN ALFA (ACTIVATED)': 'N/A',
#  'DULOXETINE': 'N/A',
#  'DULAGLUTIDE': 'N/A',
#  'DUPILUMAB': 'N/A',
#  'DURVALUMAB': 'N/A',
#  'DUTASTERIDE': 'N/A',
#  'DYCLONINE': 'N/A',
#  'DYSMENORRHEA RELIEF': 'N/A',
#  'DUVELISIB': 'N/A',
#  'ECALLANTIDE': 'N/A',
#  'ECHINACEA ANGUSTIFOLIA': 'N/A',
#  'ECONAZOLE': 'N/A',
#  'ECHINACEA PURPUREA': 'N/A',
#  'ECOTHIOPATE': 'N/A',
#  'EDROPHONIUM': 'N/A',
#  'EDARAVONE': 'N/A',
#  'ECULIZUMAB': 'N/A',
#  'EDOXABAN': 'N/A',
#  'EDETIC ACID': 'N/A',
#  'EFALIZUMAB': 'N/A',
#  'EFAVIRENZ': 'N/A',
#  'EFINACONAZOLE': 'N/A',
#  'EFLORNITHINE': 'N/A',
#  'ELAEIS GUINEENSIS': 'N/A',
#  'EFMOROCTOCOG ALFA': 'N/A',
#  'ELAGOLIX': 'N/A',
#  'EFTRENONACOG ALFA': 'N/A',
#  'ELAPEGADEMASE': 'N/A',
#  'ELBASVIR': 'N/A',
#  'ELASTIN': 'N/A',
#  'ELECTROLYTES/REPLACERS': 'N/A',
#  'ELECTROLYTE SOLUTIONS': 'N/A',
#  'ELETRIPTAN': 'N/A',
#  'ELEUTHEROCOCCUS SENTICOSUS': 'N/A',
#  'ELUXADOLINE': 'N/A',
#  'ELVITEGRAVIR': 'N/A',
#  'ELOSULFASE ALFA': 'N/A',
#  'ELIGLUSTAT': 'N/A',
#  'ELETTARIA CARDAMOMUM': 'N/A',
#  'ELOTUZUMAB': 'N/A',
#  'ELTROMBOPAG': 'N/A',
#  'EMEDASTINE': 'N/A',
#  'EMAPALUMAB': 'N/A',
#  'ENALAPRIL': 'N/A',
#  'EMOLLIENT': 'N/A',
#  'EMICIZUMAB': 'N/A',
#  'EMTRICITABINE': 'N/A',
#  'ENASIDENIB': 'N/A',
#  'EMULSIFYING WAX': 'N/A',
#  'EMPAGLIFLOZIN': 'N/A',
#  'ENALAPRILAT': 'N/A',
#  'ENCORAFENIB': 'N/A',
#  'ENFLURANE': 'N/A',
#  'ENFUVIRTIDE': 'N/A',
#  'ENOXACIN': 'N/A',
#  'ENOXAPARIN SODIUM': 'N/A',
#  'ENROFLOXACIN': 'N/A',
#  'ENZALUTAMIDE': 'N/A',
#  'ENTECAVIR': 'N/A',
#  'ENTACAPONE': 'N/A',
#  'ENOXOLONE': 'N/A',
#  'ENZYME (UNSPECIFIED)': 'N/A',
#  'EPHEDRA DISTACHYA': 'N/A',
#  'EPHEDRINE': 'N/A',
#  'EPINASTINE': 'N/A',
#  'EPIRUBICIN': 'N/A',
#  'EPIMEDIUM GRANDIFLORUM': 'N/A',
#  'EPOETIN ALFA': 'N/A',
#  'EPIGALLOCATECHIN GALLATE': 'N/A',
#  'EPINEPHRINE': 'N/A',
#  'EPLERENONE': 'N/A',
#  'EPOETIN ZETA': 'N/A',
#  'EPOPROSTENOL': 'N/A',
#  'EPROSARTAN': 'N/A',
#  'EQUISETUM ARVENSE': 'N/A',
#  'EQUISETUM HIEMALE': 'N/A',
#  'EPTACOG ALFA (ACTIVATED)': 'N/A',
#  'EPTIFIBATIDE': 'N/A',
#  'ERAVACYCLINE': 'N/A',
#  'ERGOMETRINE': 'N/A',
#  'ERGOCALCIFEROL': 'N/A',
#  'ERGOTAMINE': 'N/A',
#  'ERENUMAB': 'N/A',
#  'ERIBULIN': 'N/A',
#  'ERLOTINIB': 'N/A',
#  'ERTAPENEM': 'N/A',
#  'ERIODICTYON CALIFORNICUM': 'N/A',
#  'ERTUGLIFLOZIN': 'N/A',
#  'ESKETAMINE': 'N/A',
#  'ESLICARBAZEPINE ACETATE': 'N/A',
#  'ERYTHROMYCIN': 'N/A',
#  'ESMOLOL': 'N/A',
#  'ESCITALOPRAM': 'N/A',
#  'ESOMEPRAZOLE': 'N/A',
#  'ESTAZOLAM': 'N/A',
#  'ESTRAMUSTINE': 'N/A',
#  'ESTRADIOL': 'N/A',
#  'ESTRIOL': 'N/A',
#  'ESTROGENIC SUBSTANCES- CONJUGATED': 'N/A',
#  'ESTROGENIC SUBSTANCE': 'N/A',
#  'ESTRONE': 'N/A',
#  'ESZOPICLONE': 'N/A',
#  'ESTROGENIC SUBSTANCES- ESTERIFIED': 'N/A',
#  'ETACRYNIC ACID': 'N/A',
#  'ETELCALCETIDE': 'N/A',
#  'ETEPLIRSEN': 'N/A',
#  'ETHAMBUTOL': 'N/A',
#  'ETANERCEPT': 'N/A',
#  'ETHANOLAMINE': 'N/A',
#  'ETHCHLORVYNOL': 'N/A',
#  'ETHINYLESTRADIOL BETADEX': 'N/A',
#  'ETHANOL': 'N/A',
#  'ETHINYLESTRADIOL': 'N/A',
#  'ETHIONAMIDE': 'N/A',
#  'ETHOSUXIMIDE': 'N/A',
#  'ETHYLENE GLYCOL': 'N/A',
#  'ETHYL-EICOSAPENT': 'N/A',
#  'ETHOTOIN': 'N/A',
#  'ETIDOCAINE': 'N/A',
#  'ETIDRONIC ACID': 'N/A',
#  'ETODOLAC': 'N/A',
#  'ETOMIDATE': 'N/A',
#  ...}

# %%
compound = pcp.get_compounds("Nickel", 'name')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/pubchempy.py:271, in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     270 log.debug('Request data: %s', postdata)
# --> 271 response = urlopen(apiurl, postdata)
#     272 return response
#
# File /usr/local/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/local/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/local/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/local/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File /usr/local/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File /usr/local/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 503: PUGREST.ServerBusy
#
# During handling of the above exception, another exception occurred:
#
# PubChemHTTPError                          Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 compound = pcp.get_compounds("Nickel", 'name')
#
# File /usr/local/lib/python3.11/site-packages/pubchempy.py:321, in get_compounds(identifier, namespace, searchtype, as_dataframe, **kwargs)
#     312 def get_compounds(identifier, namespace='cid', searchtype=None, as_dataframe=False, **kwargs):
#     313     """Retrieve the specified compound records from PubChem.
#     314
#     315     :param identifier: The compound identifier to use as a search query.
#    (...)
#     319                          :class:`~pandas.DataFrame` and return that.
#     320     """
# --> 321     results = get_json(identifier, namespace, searchtype=searchtype, **kwargs)
#     322     compounds = [Compound(r) for r in results['PC_Compounds']] if results else []
#     323     if as_dataframe:
#
# File /usr/local/lib/python3.11/site-packages/pubchempy.py:299, in get_json(identifier, namespace, domain, operation, searchtype, **kwargs)
#     297 """Request wrapper that automatically parses JSON response and supresses NotFoundError."""
#     298 try:
# --> 299     return json.loads(get(identifier, namespace, domain, operation, 'JSON', searchtype, **kwargs).decode())
#     300 except NotFoundError as e:
#     301     log.info(e)
#
# File /usr/local/lib/python3.11/site-packages/pubchempy.py:292, in get(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     290             response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     291 else:
# --> 292     response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     293 return response
#
# File /usr/local/lib/python3.11/site-packages/pubchempy.py:274, in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     272     return response
#     273 except HTTPError as e:
# --> 274     raise PubChemHTTPError(e)
#
# PubChemHTTPError: 'PUGREST.ServerBusy'
