# %%
import pandas as pd

# %%
margaret = pd.read_excel('inxight_data_Margaret.xlsx', engine='openpyxl')
margaret
# Out:
#                                            url  \
# 0       https://drugs.ncats.io/drug/L2B0WJF7ZY
# 1       https://drugs.ncats.io/drug/997WVV895X
# 2       https://drugs.ncats.io/drug/1EJ6Z6Q368
# 3       https://drugs.ncats.io/drug/8110R61I4U
# 4       https://drugs.ncats.io/drug/7V4A8U16MB
# ...                                        ...
# 107347  https://drugs.ncats.io/drug/62204K0Y95
# 107348  https://drugs.ncats.io/drug/483ONS63WN
# 107349  https://drugs.ncats.io/drug/SQS1FA1FGW
# 107350  https://drugs.ncats.io/drug/8XM2XT8VWI
# 107351  https://drugs.ncats.io/drug/QA846JAV5B
#
#                                                    common  \
# 0       ['LACTITOL ANHYDROUS', 'LACTOBIOSIT', 'MIRUHEN...
# 1       ['BHV-3000', 'RIMEGEPANT [INN]', 'RIMEGEPANT [...
# 2       ['PENTADECANEDIOIC ACID, 8-HYDROXY-2,2,14,14-T...
# 3       ['AMISULPRIDE [EP]', 'AMISULPRIDE [WHO-DD]', '...
# 4           ['REMIMAZOLAM [INN]', 'REMIMAZOLAM [WHO-DD]']
# ...

# %% [markdown]
# ### Task 1:
#
# - Identify drugs in Margaret’s data launched in the US without CAS values
# - Utilize PubChem to retrieve these CAS values
# - Address cases where drugs have PubChem numbers instead of CAS
# - For combination drugs, retrieve CAS values for individual components if available

# %%
missing_cas = margaret[(margaret['first_year_approval'].notna()) & (margaret['cas'].isna())]
missing_cas
# Out:
#                                            url  \
# 194     https://drugs.ncats.io/drug/9H414A99MD
# 272     https://drugs.ncats.io/drug/CLH5FT6412
# 616     https://drugs.ncats.io/drug/06A33308KH
# 677     https://drugs.ncats.io/drug/550Z839889
# 851     https://drugs.ncats.io/drug/4877X14G4C
# ...                                        ...
# 107239  https://drugs.ncats.io/drug/CX39D2R810
# 107240  https://drugs.ncats.io/drug/5I5HVC73I8
# 107305  https://drugs.ncats.io/drug/23O68KB9KV
# 107307  https://drugs.ncats.io/drug/S9U4ZR2W8V
# 107308  https://drugs.ncats.io/drug/5377795HRF
#
#                                                    common  \
# 194     ['RADIUM RA-223 CATION', 'RADIUM, ISOTOPE OF M...
# 272          ['FERUMOXYTOL NON-STOICHIOMETRIC MAGNETITE']
# 616     ['STRONTIUM CATION SR-89', 'STRONTIUM-89', 'ST...
# 677     ['RUBIDIUM CATION RB-82', '((SUP 82)RB)RUBIDIU...
# 851     ['THALLOUS CATION TL-201', 'THALLIUM CATION TL...
# ...

# %%
missing_cas.to_csv('margaret_missing_cas.csv', index=False)
