# %%
import pandas as pd
import numpy as np

cortellis = pd.read_csv("cortellis_launched_drugs_withcas.csv")
iqvia = pd.read_excel("iqvia_drugs_notmatched_to_pubchem_cas.xlsx")

# %%
cortellis.head(15)
# Out:
#     drugid                      cas
# 0     2428                  58-61-7
# 1     2485                 745-65-3
# 2     2565               74863-84-6
# 3     2587               83905-01-5
# 4     2687   91714-93-1; 91714-94-2
# 5     2695   52485-79-7; 53152-21-9
# 6     2736  123171-59-5; 88040-23-7
# 7     2752   83881-51-0; 83881-52-1
# 8     2816   88768-40-5; 90139-06-3
# 9     2929     3239-44-9; 3239-45-0
# 10    2959   20830-81-3; 23541-50-6
# 11    2963      57-63-6; 67392-87-4
# 12    3046               73121-56-9
# 13    3066                  50-28-2
# 14    3121   72479-26-6; 73151-29-8

# %%
iqvia.head(15)
# Out:
#                                              molecule                crp  \
# 0   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 1   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 2   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 3   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 4   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 5   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 6   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 7                         2-PROPANOL#BENZOYL_PEROXIDE        LAB_UNKNOWN
# 8                         2-PROPANOL#BENZOYL_PEROXIDE        LAB_UNKNOWN
# 9                2-PROPANOL#KETOROLAC#POVIDONE-IODINE      TERRAIN_PHARM
# 10               2-PROPANOL#KETOROLAC#POVIDONE-IODINE      TERRAIN_PHARM
# 11               2-PROPANOL#KETOROLAC#POVIDONE-IODINE      TERRAIN_PHARM
# 12  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 13  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 14  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
#
#                 intprd        component_name       parsed_molecule  \
# 0     LOPROX CREAM KIT         1-HEXADECANOL         1 HEXADECANOL
# 1     LOPROX CREAM KIT      ANTHEMIS_NOBILIS      ANTHEMIS NOBILIS
# 2     LOPROX CREAM KIT  BUTYROSPERMUM_PARKII  BUTYROSPERMUM PARKII
# 3     LOPROX CREAM KIT            CICLOPIROX            CICLOPIROX
# 4     LOPROX CREAM KIT              GLYCEROL              GLYCEROL
# 5     LOPROX CREAM KIT       HYALURONIC_ACID       HYALURONIC ACID
# 6     LOPROX CREAM KIT        SALICYLIC_ACID        SALICYLIC ACID
# 7   2-PROP/BENZ   L.U.            2-PROPANOL            2 PROPANOL
# 8   2-PROP/BENZ   L.U.      BENZOYL_PEROXIDE      BENZOYL PEROXIDE
# 9   KETOROLAC     TEHR            2-PROPANOL            2 PROPANOL
# 10  KETOROLAC     TEHR             KETOROLAC             KETOROLAC
# 11  KETOROLAC     TEHR       POVIDONE-IODINE       POVIDONE-IODINE
# 12             ALTERIL   4-AMINOBUTYRIC_ACID   4 AMINOBUTYRIC ACID
# 13             ALTERIL               GLYCINE               GLYCINE
# 14             ALTERIL       HUMULUS_LUPULUS       HUMULUS LUPULUS
#
#                                                  link result_type  \
# 0      https://pubchem.ncbi.nlm.nih.gov/compound/2682    RELEVANT
# 1   https://pubchem.ncbi.nlm.nih.gov/compound/Cham...    FEATURED
# 2   https://pubchem.ncbi.nlm.nih.gov/compound/Vite...    FEATURED
# 3      https://pubchem.ncbi.nlm.nih.gov/compound/2749    FEATURED
# 4       https://pubchem.ncbi.nlm.nih.gov/compound/753    FEATURED
# 5   https://pubchem.ncbi.nlm.nih.gov/compound/Hyal...    FEATURED
# 6       https://pubchem.ncbi.nlm.nih.gov/compound/338    FEATURED
# 7      https://pubchem.ncbi.nlm.nih.gov/compound/3776    FEATURED
# 8      https://pubchem.ncbi.nlm.nih.gov/compound/7187    FEATURED
# 9      https://pubchem.ncbi.nlm.nih.gov/compound/3776    FEATURED
# 10     https://pubchem.ncbi.nlm.nih.gov/compound/3826    FEATURED
# 11  https://pubchem.ncbi.nlm.nih.gov/compound/Povi...    FEATURED
# 12      https://pubchem.ncbi.nlm.nih.gov/compound/119    FEATURED
# 13      https://pubchem.ncbi.nlm.nih.gov/compound/750    FEATURED
# 14   https://pubchem.ncbi.nlm.nih.gov/compound/639665    RELEVANT
#
#                                  cas  \
# 0   36653-82-4, 36311-34-9, 124-29-8
# 1                        977007-26-3
# 2                        No CAS info
# 3                         29342-05-0
# 4                            56-81-5
# 5                          9004-61-9
# 6                            69-72-7
# 7                            67-63-0
# 8                            94-36-0
# 9                            67-63-0
# 10            74103-06-3, 66635-83-4
# 11                        25655-41-8
# 12                           56-12-2
# 13   56-40-6, 25718-94-9, 18875-39-3
# 14                       No CAS info
#
#                                        deprecated_cas cmpnd_or_subst  \
# 0   168679-13-8, 124-29-8, 55069-45-9, 8014-51-5, ...       COMPOUND
# 1                                         No CAS info       COMPOUND
# 2                                         No CAS info       COMPOUND
# 3                                         No CAS info       COMPOUND
# 4   29796-42-7, 30049-52-6, 37228-54-9, 75398-78-6...       COMPOUND
# 5   29382-75-0, 37243-73-5, 9039-38-7, 165324-65-2...       COMPOUND
# 6   7681-06-3, 8052-31-1, 1186130-36-8, 1186130-36...       COMPOUND
# 7                                           8013-70-5       COMPOUND
# 8   117989-71-6, 143928-58-9, 37370-29-9, 132323-4...       COMPOUND
# 9                                           8013-70-5       COMPOUND
# 10                                         66635-83-4       COMPOUND
# 11  113813-78-8, 129947-86-0, 130095-86-2, 138115-...       COMPOUND
# 12                                          3131-86-0       COMPOUND
# 13  52955-63-2, 57678-19-0, 87867-94-5, 848646-45-...       COMPOUND
# 14                                        No CAS info       COMPOUND
#
#    in_depositor_synonym_list in_regular_synonym_list synonym  \
# 0                        YES                     YES     YES
# 1                    MISSING                     YES     YES
# 2                    MISSING                     YES     YES
# 3                        YES                     YES     YES
# 4                        YES                     YES     YES
# 5                    MISSING                     YES     YES
# 6                        YES                     YES     YES
# 7                        YES                     YES     YES
# 8                        YES                     YES     YES
# 9                        YES                     YES     YES
# 10                       YES                     YES     YES
# 11                   MISSING                     YES     YES
# 12                       YES                     YES     YES
# 13                       YES                     YES     YES
# 14                        NO                      NO      NO
#
#    cas_guess_uncertain
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14           6754-58-1

# %%
# Step 1 & 2: Expand the cortellis dataframe to have one CAS per row.
cortellis_expanded = cortellis.set_index('drugid')['cas'].str.split('; ', expand=True).stack().reset_index(name='cas')
cortellis_expanded.sort_values(by=['drugid']).head(10)
# Out:
#    drugid  level_1          cas
# 0    2428        0      58-61-7
# 1    2485        0     745-65-3
# 2    2565        0   74863-84-6
# 3    2587        0   83905-01-5
# 4    2687        0   91714-93-1
# 5    2687        1   91714-94-2
# 6    2695        0   52485-79-7
# 7    2695        1   53152-21-9
# 8    2736        0  123171-59-5
# 9    2736        1   88040-23-7

# %%
# Step 1 & 2: Do the same for iqvia dataframe, both for cas and deprecated_cas.
# iqvia_expanded = iqvia.set_index(iqvia.columns.drop(['cas', 'deprecated_cas'], 1).tolist())
# iqvia_expanded = iqvia_expanded['cas'].str.split(', ', expand=True).stack().reset_index(name='cas')
# iqvia_deprecated_expanded = iqvia.set_index(iqvia.columns.drop(['cas', 'deprecated_cas'], 1).tolist())
# iqvia_deprecated_expanded = iqvia_deprecated_expanded['deprecated_cas'].str.split(', ', expand=True).stack().reset_index(name='deprecated_cas')
# iqvia_deprecated_expanded.head(20)
iqvia['cas_both'] = iqvia['cas'] + ', ' + iqvia['deprecated_cas']
iqvia.head()
# Out:
#                                             molecule                crp  \
# 0  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 1  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 2  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 3  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 4  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
#
#              intprd        component_name       parsed_molecule  \
# 0  LOPROX CREAM KIT         1-HEXADECANOL         1 HEXADECANOL
# 1  LOPROX CREAM KIT      ANTHEMIS_NOBILIS      ANTHEMIS NOBILIS
# 2  LOPROX CREAM KIT  BUTYROSPERMUM_PARKII  BUTYROSPERMUM PARKII
# 3  LOPROX CREAM KIT            CICLOPIROX            CICLOPIROX
# 4  LOPROX CREAM KIT              GLYCEROL              GLYCEROL
#
#                                                 link result_type  \
# 0     https://pubchem.ncbi.nlm.nih.gov/compound/2682    RELEVANT
# 1  https://pubchem.ncbi.nlm.nih.gov/compound/Cham...    FEATURED
# 2  https://pubchem.ncbi.nlm.nih.gov/compound/Vite...    FEATURED
# 3     https://pubchem.ncbi.nlm.nih.gov/compound/2749    FEATURED
# 4      https://pubchem.ncbi.nlm.nih.gov/compound/753    FEATURED
#
#                                 cas  \
# 0  36653-82-4, 36311-34-9, 124-29-8
# 1                       977007-26-3
# 2                       No CAS info
# 3                        29342-05-0
# 4                           56-81-5
#
#                                       deprecated_cas cmpnd_or_subst  \
# 0  168679-13-8, 124-29-8, 55069-45-9, 8014-51-5, ...       COMPOUND
# 1                                        No CAS info       COMPOUND
# 2                                        No CAS info       COMPOUND
# 3                                        No CAS info       COMPOUND
# 4  29796-42-7, 30049-52-6, 37228-54-9, 75398-78-6...       COMPOUND
#
#   in_depositor_synonym_list in_regular_synonym_list synonym  \
# 0                       YES                     YES     YES
# 1                   MISSING                     YES     YES
# 2                   MISSING                     YES     YES
# 3                       YES                     YES     YES
# 4                       YES                     YES     YES
#
#   cas_guess_uncertain                                           cas_both
# 0                 NaN  36653-82-4, 36311-34-9, 124-29-8, 168679-13-8,...
# 1                 NaN                           977007-26-3, No CAS info
# 2                 NaN                           No CAS info, No CAS info
# 3                 NaN                            29342-05-0, No CAS info
# 4                 NaN  56-81-5, 29796-42-7, 30049-52-6, 37228-54-9, 7...

# %%
iqvia = iqvia.drop(['component_name', 'parsed_molecule', 'link', 'result_type', 'cas', 'deprecated_cas', 'cmpnd_or_subst', 'in_depositor_synonym_list', 'in_regular_synonym_list', 'synonym', 'cas_guess_uncertain'], axis = 1)
iqvia.head(20)
# Out:
#                                              molecule                crp  \
# 0   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 1   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 2   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 3   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 4   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 5   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 6   1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 7                         2-PROPANOL#BENZOYL_PEROXIDE        LAB_UNKNOWN
# 8                         2-PROPANOL#BENZOYL_PEROXIDE        LAB_UNKNOWN
# 9                2-PROPANOL#KETOROLAC#POVIDONE-IODINE      TERRAIN_PHARM
# 10               2-PROPANOL#KETOROLAC#POVIDONE-IODINE      TERRAIN_PHARM
# 11               2-PROPANOL#KETOROLAC#POVIDONE-IODINE      TERRAIN_PHARM
# 12  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 13  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 14  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 15  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 16  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 17  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 18  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
# 19  4-AMINOBUTYRIC_ACID#GLYCINE#HUMULUS_LUPULUS#MA...       BIOTAB_NUTRA
#
#                 intprd                                           cas_both
# 0     LOPROX CREAM KIT  36653-82-4, 36311-34-9, 124-29-8, 168679-13-8,...
# 1     LOPROX CREAM KIT                           977007-26-3, No CAS info
# 2     LOPROX CREAM KIT                           No CAS info, No CAS info
# 3     LOPROX CREAM KIT                            29342-05-0, No CAS info
# 4     LOPROX CREAM KIT  56-81-5, 29796-42-7, 30049-52-6, 37228-54-9, 7...
# 5     LOPROX CREAM KIT  9004-61-9, 29382-75-0, 37243-73-5, 9039-38-7, ...
# 6     LOPROX CREAM KIT  69-72-7, 7681-06-3, 8052-31-1, 1186130-36-8, 1...
# 7   2-PROP/BENZ   L.U.                                 67-63-0, 8013-70-5
# 8   2-PROP/BENZ   L.U.  94-36-0, 117989-71-6, 143928-58-9, 37370-29-9,...
# 9   KETOROLAC     TEHR                                 67-63-0, 8013-70-5
# 10  KETOROLAC     TEHR                 74103-06-3, 66635-83-4, 66635-83-4
# 11  KETOROLAC     TEHR  25655-41-8, 113813-78-8, 129947-86-0, 130095-8...
# 12             ALTERIL                                 56-12-2, 3131-86-0
# 13             ALTERIL  56-40-6, 25718-94-9, 18875-39-3, 52955-63-2, 5...
# 14             ALTERIL                           No CAS info, No CAS info
# 15             ALTERIL                           No CAS info, No CAS info
# 16             ALTERIL                   73-31-4, 8041-44-9, 1581233-31-9
# 17             ALTERIL                           No CAS info, No CAS info
# 18             ALTERIL                           No CAS info, No CAS info
# 19             ALTERIL  73-22-3, 6912-86-3, 80206-30-0, 154635-35-5, 2...

# %%
# Split 'cas_both' into lists of CAS numbers
iqvia['cas_both'] = iqvia['cas_both'].str.split(', ')

# Explode the DataFrame so each CAS number gets its own row
exploded_iqvia = iqvia.explode('cas_both')
exploded_iqvia.head()
# Out:
#                                             molecule                crp  \
# 0  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 0  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 0  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 0  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 0  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
#
#              intprd     cas_both
# 0  LOPROX CREAM KIT   36653-82-4
# 0  LOPROX CREAM KIT   36311-34-9
# 0  LOPROX CREAM KIT     124-29-8
# 0  LOPROX CREAM KIT  168679-13-8
# 0  LOPROX CREAM KIT     124-29-8

# %%
exploded_iqvia = exploded_iqvia.drop_duplicates()
exploded_iqvia
# Out:
#                                                molecule                 crp  \
# 0     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 0     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 0     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 0     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 0     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# ...                                                 ...                 ...
# 1857                                         VALRUBICIN  ENDO_INTERNATIONAL
# 1858                                 VECURONIUM_BROMIDE          MERCK_&_CO
# 1858                                 VECURONIUM_BROMIDE          MERCK_&_CO
# 1858                                 VECURONIUM_BROMIDE          MERCK_&_CO
# 1858                                 VECURONIUM_BROMIDE          MERCK_&_CO
#
#                 intprd     cas_both
# 0     LOPROX CREAM KIT   36653-82-4
# 0     LOPROX CREAM KIT   36311-34-9
# 0     LOPROX CREAM KIT     124-29-8
# 0     LOPROX CREAM KIT  168679-13-8
# 0     LOPROX CREAM KIT   55069-45-9
# ...                ...          ...
# 1857      VALSTAR ENDN  136816-53-0
# 1858          NORCURON   50700-72-6
# 1858          NORCURON   63884-29-7
# 1858          NORCURON   72254-12-7
# 1858          NORCURON   74531-67-2
#
# [9180 rows x 4 columns]

# %%
exploded_iqvia.rename(columns={'cas_both': 'cas'}, inplace=True)

merged = pd.merge(
    exploded_iqvia, cortellis_expanded, how="left", on=["cas"]
)

# %%
merged[merged['drugid'].notnull()]
# Out:
#                                                 molecule                 crp  \
# 25     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 26     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 27     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 28     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 48                           2-PROPANOL#BENZOYL_PEROXIDE         LAB_UNKNOWN
# ...                                                  ...                 ...
# 9960        PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 9961        PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 9962        PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 9993                                        TEMOZOLOMIDE          MERCK_&_CO
# 10029                                         VALRUBICIN  ENDO_INTERNATIONAL
#
#                    intprd         cas    drugid  level_1
# 25       LOPROX CREAM KIT   9004-61-9    6807.0      0.0
# 26       LOPROX CREAM KIT   9004-61-9    7103.0      0.0
# 27       LOPROX CREAM KIT   9004-61-9   13469.0      0.0
# 28       LOPROX CREAM KIT   9004-61-9  105492.0      0.0
# 48     2-PROP/BENZ   L.U.     94-36-0   78987.0      1.0
# ...                   ...         ...       ...      ...
# 9960             ALLERX D     90-82-4   13110.0      1.0
# 9961             ALLERX D     90-82-4   91390.0      2.0
# 9962             ALLERX D     90-82-4   91396.0      1.0
# 9993         TEMODAL M-CO  85622-93-1    4529.0      0.0
# 10029        VALSTAR ENDN  56124-62-0   11295.0      0.0
#
# [1296 rows x 6 columns]

# %%
# Aggregate drugid into a list for each unique combination of CAS, molecule, crp, and intprd
aggregated = merged.groupby(['molecule', 'crp', 'intprd', 'cas'])['drugid'].apply(list).reset_index()
aggregated.head()
# Out:
#                                             molecule                crp  \
# 0  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 1  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 2  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 3  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
# 4  1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...  MEDIMETRIKS_PHARM
#
#              intprd           cas drugid
# 0  LOPROX CREAM KIT  1173838-87-3  [nan]
# 1  LOPROX CREAM KIT  1186130-36-8  [nan]
# 2  LOPROX CREAM KIT      124-29-8  [nan]
# 3  LOPROX CREAM KIT  1257406-45-3  [nan]
# 4  LOPROX CREAM KIT  1357910-24-7  [nan]

# %%
cleaned_df = aggregated[~aggregated['drugid'].apply(lambda x: 'nan' in [str(i).lower() for i in x])]
cleaned_df
# Out:
#                                                molecule                 crp  \
# 35    1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 49                          2-PROPANOL#BENZOYL_PEROXIDE         LAB_UNKNOWN
# 65                 2-PROPANOL#KETOROLAC#POVIDONE-IODINE       TERRAIN_PHARM
# 126   ACACIA_CATECHU#CHONDROITINSULFURIC_ACID#GLUCOS...   RECKITT_BENCKISER
# 233   ACETIC_ACID#CALCIUM#FIBRINOGEN#GLYCINE#SODIUM#...   JOHNSON_&_JOHNSON
# ...                                                 ...                 ...
# 8985            PHYTOSTEROLS_(UNSPECIFIED)#PROGESTERONE   SAYGE_BIOSCIENCES
# 9018                                        POLIDOCANOL                MERZ
# 9110       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 9138                                       TEMOZOLOMIDE          MERCK_&_CO
# 9175                                         VALRUBICIN  ENDO_INTERNATIONAL
#
#                   intprd         cas                               drugid
# 35      LOPROX CREAM KIT   9004-61-9  [6807.0, 7103.0, 13469.0, 105492.0]
# 49    2-PROP/BENZ   L.U.     94-36-0                            [78987.0]
# 65    KETOROLAC     TEHR  74103-06-3                    [3422.0, 55698.0]
# 126   MOVE FREE ADV PLUS   9004-61-9  [6807.0, 7103.0, 13469.0, 105492.0]
# 233             CROSSEAL   1197-18-8                            [51370.0]
# ...                  ...         ...                                  ...
# 8985  BALANCE HRT NATURA     57-83-0                            [40649.0]
# 9018             ASCLERA   9002-92-0                            [88713.0]
# 9110            ALLERX D     90-82-4          [13110.0, 91390.0, 91396.0]
# 9138        TEMODAL M-CO  85622-93-1                             [4529.0]
# 9175        VALSTAR ENDN  56124-62-0                            [11295.0]
#
# [441 rows x 5 columns]

# %%
cleaned_df.head(50)
# Out:
#                                                molecule                 crp  \
# 35    1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 49                          2-PROPANOL#BENZOYL_PEROXIDE         LAB_UNKNOWN
# 65                 2-PROPANOL#KETOROLAC#POVIDONE-IODINE       TERRAIN_PHARM
# 126   ACACIA_CATECHU#CHONDROITINSULFURIC_ACID#GLUCOS...   RECKITT_BENCKISER
# 233   ACETIC_ACID#CALCIUM#FIBRINOGEN#GLYCINE#SODIUM#...   JOHNSON_&_JOHNSON
# 330   ACETYLCYSTEINE#ALLIUM_SATIVUM#ANGELICA_ARCHANG...              IOVATE
# 338   ACETYLCYSTEINE#ALLIUM_SATIVUM#ANGELICA_ARCHANG...              IOVATE
# 399   ACETYLCYSTEINE#ANGELICA_POLIMORPHA#ASCORBIC_AC...              IOVATE
# 457   ACETYLCYSTEINE#ASCORBIC_ACID#CALCIUM_LEVOFOLIN...      CENTURION_LABS
# 472   ACETYLCYSTEINE#ASCORBIC_ACID#CALCIUM_LEVOFOLIN...      CENTURION_LABS
# 500   ACETYLCYSTEINE#LEVOMEFOLIC_ACID#MECOBALAMIN#SC...              ESTEVE
# 507   ACETYLCYSTEINE#PETASITES_OFFICINALIS#PICRORRHI...              IOVATE
# 515   ACETYLSALICYLIC_ACID#CAFFEINE#CHLORPHENAMINE#P...               BAYER
# 521   ACETYLSALICYLIC_ACID#CAFFEINE#CHLORPHENAMINE#P...               BAYER
# 528   ACETYLSALICYLIC_ACID#CAFFEINE#PARACETAMOL#SALI...       GENTEX_PHARMA
# 535   ACETYLSALICYLIC_ACID#CAFFEINE#PARACETAMOL#SALI...       GENTEX_PHARMA
# 549                   ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 550                   ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 558     ACETYLSALICYLIC_ACID#PHYTOSTEROLS_(UNSPECIFIED)               BAYER
# 561                                 ACICLOVIR#LIDOCAINE       ALLEGIS_PHARM
# 562                                 ACICLOVIR#LIDOCAINE       ALLEGIS_PHARM
# 827                   ALOE_BARBADENSIS#BENZOYL_PEROXIDE             MISSION
# 853   ALOE_BARBADENSIS#BENZOYL_PEROXIDE#HAMAMELIS_VI...   UNIV_MEDICAL_PROD
# 871    ALOE_BARBADENSIS#BENZOYL_PEROXIDE#SALICYLIC_ACID  WALTMAN_PHARMCEUTI
# 955   ALOE_BARBADENSIS#COLLAGEN#HYALURONIC_ACID#LIDO...         MPM_MEDICAL
# 972   ALOE_BARBADENSIS#COLLAGEN#HYALURONIC_ACID#LIDO...         MPM_MEDICAL
# 1014            ALOE_BARBADENSIS#HYALURONIC_ACID#SODIUM       NEILMED_PHARM
# 1030            ALOE_BARBADENSIS#HYDROCORTISONE#MENTHOL        WRASER_PHARM
# 1047         ALOE_BARBADENSIS#HYDROCORTISONE#PRAMOCAINE    NOVUM_PHARMA_LLC
# 1056                         ALOE_BARBADENSIS#LIDOCAINE         LAB_UNKNOWN
# 1071               ALOE_BARBADENSIS#LIDOCAINE#VITAMIN_E         MPM_MEDICAL
# 1088                            ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 1091                            ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 1179  ALTHAEA_OFFICINALIS#ARGANIA_SPINOSA#BRASSICA_C...             PURETEK
# 1188  ALTHAEA_OFFICINALIS#ARGANIA_SPINOSA#BRASSICA_C...             PURETEK
# 1251  ALUMINIUM#DIPHENHYDRAMINE#LIDOCAINE#MAGNESIUM#...        CUTIS_PHARMA
# 1300                                 AMIODARONE#GLUCOSE          PHARMEDIUM
# 1351            AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 1353            AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 1362              AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 1364              AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 1366              AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 1442                                         ARGATROBAN            NOVARTIS
# 1445                              ARTICAINE#EPINEPHRINE             PIERREL
# 1588  ASCORBIC_ACID#BETACAROTENE#BIOTIN#CARBONYL_IRO...  JUBILANT_LIFE_SCIE
# 1593  ASCORBIC_ACID#BETACAROTENE#BIOTIN#CARBONYL_IRO...  JUBILANT_LIFE_SCIE
# 1607  ASCORBIC_ACID#BETACAROTENE#BIOTIN#CARBONYL_IRO...  JUBILANT_LIFE_SCIE
# 1849  ASCORBIC_ACID#BIOTIN#CARBONYL_IRON#COBALT#COPP...             PRONOVA
# 1917  ASCORBIC_ACID#BIOTIN#CARBONYL_IRON#COPPER#CYAN...        AVION_PHARMA
# 1989  ASCORBIC_ACID#BIOTIN#CARBONYL_IRON#COPPER#CYAN...  JUBILANT_LIFE_SCIE
#
#                   intprd          cas  \
# 35      LOPROX CREAM KIT    9004-61-9
# 49    2-PROP/BENZ   L.U.      94-36-0
# 65    KETOROLAC     TEHR   74103-06-3
# 126   MOVE FREE ADV PLUS    9004-61-9
# 233             CROSSEAL    1197-18-8
# 330              GERM MD      56-85-9
# 338              GERM MD     616-91-1
# 399              COLD MD     616-91-1
# 457           PURALOR CI     616-91-1
# 472           PURALOR CI   80433-71-2
# 500   METAFOLBIC PLUS RF     616-91-1
# 507           ALLERGY MD     616-91-1
# 515          CORICIDIN D     132-22-9
# 521          CORICIDIN D      50-78-2
# 528              LEVACET     103-90-2
# 535              LEVACET      50-78-2
# 549            ASASANTIN      50-78-2
# 550            ASASANTIN      58-32-2
# 558   BAYER HEART ADVANT      50-78-2
# 561              LIDOVIR     137-58-6
# 562              LIDOVIR   59277-89-3
# 827              BP MISS      94-36-0
# 853      ACNEFREE SEVERE      94-36-0
# 871     ZAPZYT ACNE PACK      94-36-0
# 955        REGENECARE HA     137-58-6
# 972        REGENECARE HA    9004-61-9
# 1014        NASOGEL NEIL    9004-61-9
# 1030               NUZON      50-23-7
# 1047            NOVACORT      50-23-7
# 1056  LIDOCAI/ALOE  L.U.     137-58-6
# 1071          REGENECARE     137-58-6
# 1088  LIOVEL COMBINATION  111025-46-8
# 1091  LIOVEL COMBINATION  850649-61-5
# 1179  DERMACINRX PHN PAK     137-58-6
# 1188  DERMACINRX ZRM PAK     137-58-6
# 1251     FIRST-MOUTHWASH     137-58-6
# 1300  AMIODARO/GLUC PRMU    1951-25-3
# 1351             PREVPAC   26787-78-0
# 1353             PREVPAC   61336-70-7
# 1362       OMECLAMOX-PAK   26787-78-0
# 1364       OMECLAMOX-PAK   61336-70-7
# 1366       OMECLAMOX-PAK   73590-58-6
# 1442  ARGATROBAN    NOVT   74863-84-6
# 1445             ORABLOC      51-43-4
# 1588             CORVITA      65-23-6
# 1593             CORVITA      68-19-9
# 1607             CORVITA      83-88-5
# 1849          HEMAX PRNO      68-19-9
# 1917            FERIVAFA      68-19-9
# 1989              TL-HEM      68-19-9
#
#                                                  drugid
# 35                  [6807.0, 7103.0, 13469.0, 105492.0]
# 49                                            [78987.0]
# 65                                    [3422.0, 55698.0]
# 126                 [6807.0, 7103.0, 13469.0, 105492.0]
# 233                                           [51370.0]
# 330                                  [69737.0, 69738.0]
# 338                                           [95553.0]
# 399                                           [95553.0]
# 457                                           [95553.0]
# 472                                           [16915.0]
# 500                                           [95553.0]
# 507                                           [95553.0]
# 515       [66158.0, 69798.0, 83624.0, 91390.0, 91711.0]
# 521                [15574.0, 19460.0, 56276.0, 64893.0]
# 528                         [48917.0, 64433.0, 68852.0]
# 535                [15574.0, 19460.0, 56276.0, 64893.0]
# 549                [15574.0, 19460.0, 56276.0, 64893.0]
# 550                                           [15574.0]
# 558                [15574.0, 19460.0, 56276.0, 64893.0]
# 561   [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 562                [44258.0, 53498.0, 87715.0, 87725.0]
# 827                                           [78987.0]
# 853                                           [78987.0]
# 871                                           [78987.0]
# 955   [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 972                 [6807.0, 7103.0, 13469.0, 105492.0]
# 1014                [6807.0, 7103.0, 13469.0, 105492.0]
# 1030                                          [48942.0]
# 1047                                          [48942.0]
# 1056  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1071  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1088                        [48279.0, 55177.0, 59795.0]
# 1091                                          [59795.0]
# 1179  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1188  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1251  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1300                                          [57749.0]
# 1351                                 [44279.0, 49017.0]
# 1353                                          [44279.0]
# 1362                                 [44279.0, 49017.0]
# 1364                                          [44279.0]
# 1366                                          [34063.0]
# 1442                                  [2565.0, 73449.0]
# 1445                                 [46891.0, 98621.0]
# 1588                                [85192.0, 109953.0]
# 1593                                 [98637.0, 98648.0]
# 1607                                          [73506.0]
# 1849                                 [98637.0, 98648.0]
# 1917                                 [98637.0, 98648.0]
# 1989                                 [98637.0, 98648.0]

# %%
grouped = cleaned_df.sort_values(by=['molecule', 'crp', 'intprd'])
# grouped.head(70)
grouped_exploded = grouped.explode('drugid').reset_index(drop=True)
grouped_exploded
# Out:
#                                                molecule                 crp  \
# 0     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 1     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 2     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 3     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 4                           2-PROPANOL#BENZOYL_PEROXIDE         LAB_UNKNOWN
# ...                                                 ...                 ...
# 1291       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 1292       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 1293       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 1294                                       TEMOZOLOMIDE          MERCK_&_CO
# 1295                                         VALRUBICIN  ENDO_INTERNATIONAL
#
#                   intprd         cas    drugid
# 0       LOPROX CREAM KIT   9004-61-9    6807.0
# 1       LOPROX CREAM KIT   9004-61-9    7103.0
# 2       LOPROX CREAM KIT   9004-61-9   13469.0
# 3       LOPROX CREAM KIT   9004-61-9  105492.0
# 4     2-PROP/BENZ   L.U.     94-36-0   78987.0
# ...                  ...         ...       ...
# 1291            ALLERX D     90-82-4   13110.0
# 1292            ALLERX D     90-82-4   91390.0
# 1293            ALLERX D     90-82-4   91396.0
# 1294        TEMODAL M-CO  85622-93-1    4529.0
# 1295        VALSTAR ENDN  56124-62-0   11295.0
#
# [1296 rows x 5 columns]

# %%
grouped.to_csv("test.csv", index=False)
grouped_exploded['drugid'] = grouped_exploded['drugid'].astype(int)

# %%
grouped_exploded.to_csv("grouped_exploded.csv", index=False)
grouped_exploded
# Out:
#                                                molecule                 crp  \
# 0     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 1     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 2     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 3     1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 4                           2-PROPANOL#BENZOYL_PEROXIDE         LAB_UNKNOWN
# ...                                                 ...                 ...
# 1291       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 1292       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 1293       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 1294                                       TEMOZOLOMIDE          MERCK_&_CO
# 1295                                         VALRUBICIN  ENDO_INTERNATIONAL
#
#                   intprd         cas  drugid
# 0       LOPROX CREAM KIT   9004-61-9    6807
# 1       LOPROX CREAM KIT   9004-61-9    7103
# 2       LOPROX CREAM KIT   9004-61-9   13469
# 3       LOPROX CREAM KIT   9004-61-9  105492
# 4     2-PROP/BENZ   L.U.     94-36-0   78987
# ...                  ...         ...     ...
# 1291            ALLERX D     90-82-4   13110
# 1292            ALLERX D     90-82-4   91390
# 1293            ALLERX D     90-82-4   91396
# 1294        TEMODAL M-CO  85622-93-1    4529
# 1295        VALSTAR ENDN  56124-62-0   11295
#
# [1296 rows x 5 columns]

# %%
# grouped_exploded = grouped_exploded.groupby(['molecule', 'crp', 'intprd'])

# # Filter groups and keep only those with more than one 'drugid' (i.e., not unique within the group)
# filtered_df = grouped_exploded.filter(lambda x: len(x['drugid'].unique()) > 1)

# # Display the filtered DataFrame
# filtered_df

# %%
# Group by 'molecule', 'crp', 'intprd', and 'drugid', then count occurrences
grouped_counts = grouped_exploded.groupby(['molecule', 'crp', 'intprd', 'drugid']).size()

# Filter to identify groups where 'drugid' appears more than once
repeated_drugid_groups = grouped_counts[grouped_counts > 1].reset_index()

# Filter original DataFrame to keep only those rows with 'drugid' appearing more than once in their group
filtered_df = grouped_exploded.merge(repeated_drugid_groups[['molecule', 'crp', 'intprd', 'drugid']], on=['molecule', 'crp', 'intprd', 'drugid'])

print(filtered_df)
# Out:
#                                     molecule                crp  \
# 0          ACETYLSALICYLIC_ACID#DIPYRIDAMOLE   BOEHRINGER_INGEL
# 1          ACETYLSALICYLIC_ACID#DIPYRIDAMOLE   BOEHRINGER_INGEL
# 2                    ALOGLIPTIN#PIOGLITAZONE             TAKEDA
# 3                    ALOGLIPTIN#PIOGLITAZONE             TAKEDA
# 4    AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE             TAKEDA
# ..                                       ...                ...
# 167                  METFORMIN#ROSIGLITAZONE    GLAXOSMITHKLINE
# 168                  METFORMIN#ROSIGLITAZONE    GLAXOSMITHKLINE
# 169                  METFORMIN#ROSIGLITAZONE    GLAXOSMITHKLINE
# 170                               PEMIROLAST  JOHNSON_&_JOHNSON
# 171                               PEMIROLAST  JOHNSON_&_JOHNSON
#
#                  intprd          cas  drugid
# 0             ASASANTIN      50-78-2   15574
# 1             ASASANTIN      58-32-2   15574
# 2    LIOVEL COMBINATION  111025-46-8   59795
# 3    LIOVEL COMBINATION  850649-61-5   59795
# 4               PREVPAC   26787-78-0   44279
# ..                  ...          ...     ...
# 167           AVANDAMET     657-24-9   49829
# 168           AVANDAMET  122320-73-4   56823
# 169           AVANDAMET     657-24-9   56823
# 170             ALAMAST  100299-08-9    6165
# 171             ALAMAST   69372-19-6    6165
#
# [172 rows x 5 columns]

# %%
filtered_df.to_csv("filtered.csv", index=False)

# %%
filtered_df.head(50)
# Out:
#                                              molecule                 crp  \
# 0                   ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 1                   ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 2                             ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 3                             ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 4             AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 5             AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 6               AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 7               AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 8    ATROPA_BELLADONNA#CHLORPHENAMINE#PSEUDOEPHEDRINE  RESPA_PHARMACEUTIC
# 9    ATROPA_BELLADONNA#CHLORPHENAMINE#PSEUDOEPHEDRINE  RESPA_PHARMACEUTIC
# 10  AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 11  AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 12  AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 13  AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 14  AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 15  AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 16  BETAINE#CALCIUM_FOLINATE#COBAMAMIDE#COCARBOXYL...       JAYMAC_PHARMA
# 17  BETAINE#CALCIUM_FOLINATE#COBAMAMIDE#COCARBOXYL...       JAYMAC_PHARMA
# 18  BETAINE#CALCIUM_FOLINATE#COBAMAMIDE#COCARBOXYL...       JAYMAC_PHARMA
# 19  BETAINE#CALCIUM_FOLINATE#COBAMAMIDE#COCARBOXYL...       JAYMAC_PHARMA
# 20  BROMPHENIRAMINE#CHLORPHENAMINE#PHENYLEPHRINE#P...    MELDEX_INTERNAT.
# 21  BROMPHENIRAMINE#CHLORPHENAMINE#PHENYLEPHRINE#P...    MELDEX_INTERNAT.
# 22        BROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PERNIX
# 23        BROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PERNIX
# 24        BROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PERNIX
# 25        BROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PERNIX
# 26                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 27                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 28                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 29                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 30                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 31                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 32                         CETIRIZINE#PSEUDOEPHEDRINE   JOHNSON_&_JOHNSON
# 33                         CETIRIZINE#PSEUDOEPHEDRINE   JOHNSON_&_JOHNSON
# 34          CHLORPHENAMINE#CLOFEDANOL#PSEUDOEPHEDRINE       JAYMAC_PHARMA
# 35          CHLORPHENAMINE#CLOFEDANOL#PSEUDOEPHEDRINE       JAYMAC_PHARMA
# 36                 CHLORPHENAMINE#CODEINE#PARACETAMOL  MCR/AMERICAN_PHARM
# 37                 CHLORPHENAMINE#CODEINE#PARACETAMOL  MCR/AMERICAN_PHARM
# 38                 CHLORPHENAMINE#CODEINE#PARACETAMOL  MCR/AMERICAN_PHARM
# 39                 CHLORPHENAMINE#CODEINE#PARACETAMOL  MCR/AMERICAN_PHARM
# 40               CHLORPHENAMINE#CODEINE#PHENYLEPHRINE       CAPITAL_PHARM
# 41               CHLORPHENAMINE#CODEINE#PHENYLEPHRINE       CAPITAL_PHARM
# 42               CHLORPHENAMINE#CODEINE#PHENYLEPHRINE       CAPITAL_PHARM
# 43               CHLORPHENAMINE#CODEINE#PHENYLEPHRINE       CAPITAL_PHARM
# 44      CHLORPHENAMINE#DIHYDROCODEINE#PSEUDOEPHEDRINE            KV_PHARM
# 45      CHLORPHENAMINE#DIHYDROCODEINE#PSEUDOEPHEDRINE            KV_PHARM
# 46     CHLORPHENAMINE#DIPHENHYDRAMINE#PSEUDOEPHEDRINE           WOCKHARDT
# 47     CHLORPHENAMINE#DIPHENHYDRAMINE#PSEUDOEPHEDRINE           WOCKHARDT
# 48  CHLORPHENAMINE#GUAIFENESIN#HYDROCODONE#PSEUDOE...         MAGNA_PHARM
# 49  CHLORPHENAMINE#GUAIFENESIN#HYDROCODONE#PSEUDOE...         MAGNA_PHARM
#
#                 intprd          cas  drugid
# 0            ASASANTIN      50-78-2   15574
# 1            ASASANTIN      58-32-2   15574
# 2   LIOVEL COMBINATION  111025-46-8   59795
# 3   LIOVEL COMBINATION  850649-61-5   59795
# 4              PREVPAC   26787-78-0   44279
# 5              PREVPAC   61336-70-7   44279
# 6        OMECLAMOX-PAK   26787-78-0   44279
# 7        OMECLAMOX-PAK   61336-70-7   44279
# 8           RESPA A.R.     132-22-9   91390
# 9           RESPA A.R.      90-82-4   91390
# 10         NICAZELDOXY   24390-14-5   10198
# 11         NICAZELDOXY     564-25-0   10198
# 12         NICAZELDOXY   24390-14-5   46927
# 13         NICAZELDOXY     564-25-0   46927
# 14         NICAZELDOXY   24390-14-5   92069
# 15         NICAZELDOXY     564-25-0   92069
# 16          ENBRACE HR   10417-94-4   70004
# 17          ENBRACE HR    6217-54-5   70004
# 18          ENBRACE HR   10417-94-4   70004
# 19          ENBRACE HR    6217-54-5   70004
# 20           SYMPAK II     132-22-9   91390
# 21           SYMPAK II      90-82-4   91390
# 22           DROCON-CS     125-29-1   91390
# 23           DROCON-CS      90-82-4   91390
# 24           DROCON-CS     125-29-1   91396
# 25           DROCON-CS      90-82-4   91396
# 26            SUBOXONE     465-65-6   64940
# 27            SUBOXONE   52485-79-7   64940
# 28            SUBOXONE     465-65-6   66004
# 29            SUBOXONE   52485-79-7   66004
# 30            SUBOXONE     465-65-6   75426
# 31            SUBOXONE   52485-79-7   75426
# 32          ZYRTEC DUO   83881-51-0   13110
# 33          ZYRTEC DUO      90-82-4   13110
# 34           DRYMAX AF     132-22-9   91390
# 35           DRYMAX AF      90-82-4   91390
# 36            COTABFLU     132-22-9   66158
# 37            COTABFLU      76-57-3   66158
# 38            COTABFLU     132-22-9   91711
# 39            COTABFLU      76-57-3   91711
# 40              CAPCOF     132-22-9   66158
# 41              CAPCOF      76-57-3   66158
# 42              CAPCOF     132-22-9   91711
# 43              CAPCOF      76-57-3   91711
# 44    HYDRO-TUSSIN DHC     132-22-9   91390
# 45    HYDRO-TUSSIN DHC      90-82-4   91390
# 46  C-PHED DPD TANNATE     132-22-9   91390
# 47  C-PHED DPD TANNATE      90-82-4   91390
# 48               ZTUSS     125-29-1   69798
# 49               ZTUSS     132-22-9   69798

# %%
merged_df = filtered_df.groupby(['molecule', 'crp', 'intprd', 'drugid'])['cas'].apply(list).reset_index()
merged_df.head(50)
# Out:
#                                              molecule                 crp  \
# 0                   ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 1                             ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 2             AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 3               AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 4    ATROPA_BELLADONNA#CHLORPHENAMINE#PSEUDOEPHEDRINE  RESPA_PHARMACEUTIC
# 5   AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 6   AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 7   AZELAIC_ACID#COPPER#CURCUMIN#DOXYCYCLINE#FOLIC...              ELORAC
# 8   BETAINE#CALCIUM_FOLINATE#COBAMAMIDE#COCARBOXYL...       JAYMAC_PHARMA
# 9   BETAINE#CALCIUM_FOLINATE#COBAMAMIDE#COCARBOXYL...       JAYMAC_PHARMA
# 10  BROMPHENIRAMINE#CHLORPHENAMINE#PHENYLEPHRINE#P...    MELDEX_INTERNAT.
# 11        BROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PERNIX
# 12        BROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PERNIX
# 13                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 14                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 15                             BUPRENORPHINE#NALOXONE            INDIVIOR
# 16                         CETIRIZINE#PSEUDOEPHEDRINE   JOHNSON_&_JOHNSON
# 17          CHLORPHENAMINE#CLOFEDANOL#PSEUDOEPHEDRINE       JAYMAC_PHARMA
# 18                 CHLORPHENAMINE#CODEINE#PARACETAMOL  MCR/AMERICAN_PHARM
# 19                 CHLORPHENAMINE#CODEINE#PARACETAMOL  MCR/AMERICAN_PHARM
# 20               CHLORPHENAMINE#CODEINE#PHENYLEPHRINE       CAPITAL_PHARM
# 21               CHLORPHENAMINE#CODEINE#PHENYLEPHRINE       CAPITAL_PHARM
# 22      CHLORPHENAMINE#DIHYDROCODEINE#PSEUDOEPHEDRINE            KV_PHARM
# 23     CHLORPHENAMINE#DIPHENHYDRAMINE#PSEUDOEPHEDRINE           WOCKHARDT
# 24  CHLORPHENAMINE#GUAIFENESIN#HYDROCODONE#PSEUDOE...         MAGNA_PHARM
# 25  CHLORPHENAMINE#GUAIFENESIN#HYDROCODONE#PSEUDOE...         MAGNA_PHARM
# 26  CHLORPHENAMINE#GUAIFENESIN#HYDROCODONE#PSEUDOE...         MAGNA_PHARM
# 27  CHLORPHENAMINE#GUAIFENESIN#HYDROCODONE#PSEUDOE...         MAGNA_PHARM
# 28         CHLORPHENAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PFIZER
# 29         CHLORPHENAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PFIZER
# 30         CHLORPHENAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PFIZER
# 31         CHLORPHENAMINE#HYDROCODONE#PSEUDOEPHEDRINE              PFIZER
# 32           CHLORPHENAMINE#IBUPROFEN#PSEUDOEPHEDRINE              PFIZER
# 33  CHLORPHENAMINE#PHENYLEPHRINE#PSEUDOEPHEDRINE#S...              CHIESI
# 34         CHLORPHENAMINE#PSEUDOEPHEDRINE#SCOPOLAMINE            CAPELLON
# 35  CHONDROITINSULFURIC_ACID#COLLAGEN#DOCONEXENT#F...      ICELAND_HEALTH
# 36                       CIPROFLOXACIN#HYDROCORTISONE            NOVARTIS
# 37                CODEINE#HYDROCODONE#PSEUDOEPHEDRINE     STEWART_JACKSON
# 38                CODEINE#HYDROCODONE#PSEUDOEPHEDRINE     STEWART_JACKSON
# 39        DASABUVIR#OMBITASVIR#PARITAPREVIR#RITONAVIR              ABBVIE
# 40     DEXBROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE      BRIGHTON_PHARM
# 41     DEXBROMPHENIRAMINE#HYDROCODONE#PSEUDOEPHEDRINE      BRIGHTON_PHARM
# 42  DOCONEXENT#DOXYCYCLINE#ICOSAPENT#LINUM_USITATI...               AKORN
# 43  DOCONEXENT#DOXYCYCLINE#ICOSAPENT#LINUM_USITATI...               AKORN
# 44  DOCONEXENT#DOXYCYCLINE#ICOSAPENT#LINUM_USITATI...               AKORN
# 45  DOCONEXENT#DOXYCYCLINE#ICOSAPENT#LINUM_USITATI...               AKORN
# 46  DOCOSAHEXANOIC_ACID#DOXYCYCLINE#ICOSAPENT#LINU...               AKORN
# 47  DOCOSAHEXANOIC_ACID#DOXYCYCLINE#ICOSAPENT#LINU...               AKORN
# 48  DOCOSAHEXANOIC_ACID#DOXYCYCLINE#ICOSAPENT#LINU...               AKORN
# 49  DOCOSAHEXANOIC_ACID#DOXYCYCLINE#ICOSAPENT#LINU...               AKORN
#
#                 intprd  drugid  \
# 0            ASASANTIN   15574
# 1   LIOVEL COMBINATION   59795
# 2              PREVPAC   44279
# 3        OMECLAMOX-PAK   44279
# 4           RESPA A.R.   91390
# 5          NICAZELDOXY   10198
# 6          NICAZELDOXY   46927
# 7          NICAZELDOXY   92069
# 8           ENBRACE HR   70004
# 9           ENBRACE HR   70004
# 10           SYMPAK II   91390
# 11           DROCON-CS   91390
# 12           DROCON-CS   91396
# 13            SUBOXONE   64940
# 14            SUBOXONE   66004
# 15            SUBOXONE   75426
# 16          ZYRTEC DUO   13110
# 17           DRYMAX AF   91390
# 18            COTABFLU   66158
# 19            COTABFLU   91711
# 20              CAPCOF   66158
# 21              CAPCOF   91711
# 22    HYDRO-TUSSIN DHC   91390
# 23  C-PHED DPD TANNATE   91390
# 24               ZTUSS   69798
# 25               ZTUSS   83624
# 26               ZTUSS   91390
# 27               ZTUSS   91396
# 28             TUSSEND   69798
# 29             TUSSEND   83624
# 30             TUSSEND   91390
# 31             TUSSEND   91396
# 32   ADVIL ALRGY SINUS   91390
# 33           ALLERX 10   91390
# 34           RESCON MX   91390
# 35  JOINT RELIEF  ICEL   70004
# 36            CIPRO HC   48942
# 37         NOTUSS UNSP   91390
# 38         NOTUSS UNSP   91396
# 39         VIEKIRA PAK  100124
# 40  DXBPM/HYCD/PE BGHP   91390
# 41  DXBPM/HYCD/PE BGHP   91396
# 42            NUTRIDOX   10198
# 43            NUTRIDOX   46927
# 44            NUTRIDOX   70004
# 45            NUTRIDOX   92069
# 46            NUTRIDOX   10198
# 47            NUTRIDOX   46927
# 48            NUTRIDOX   70004
# 49            NUTRIDOX   92069
#
#                                                   cas
# 0                                  [50-78-2, 58-32-2]
# 1                          [111025-46-8, 850649-61-5]
# 2                            [26787-78-0, 61336-70-7]
# 3                            [26787-78-0, 61336-70-7]
# 4                                 [132-22-9, 90-82-4]
# 5                              [24390-14-5, 564-25-0]
# 6                              [24390-14-5, 564-25-0]
# 7                              [24390-14-5, 564-25-0]
# 8                             [10417-94-4, 6217-54-5]
# 9                             [10417-94-4, 6217-54-5]
# 10                                [132-22-9, 90-82-4]
# 11                                [125-29-1, 90-82-4]
# 12                                [125-29-1, 90-82-4]
# 13                             [465-65-6, 52485-79-7]
# 14                             [465-65-6, 52485-79-7]
# 15                             [465-65-6, 52485-79-7]
# 16                              [83881-51-0, 90-82-4]
# 17                                [132-22-9, 90-82-4]
# 18                                [132-22-9, 76-57-3]
# 19                                [132-22-9, 76-57-3]
# 20                                [132-22-9, 76-57-3]
# 21                                [132-22-9, 76-57-3]
# 22                                [132-22-9, 90-82-4]
# 23                                [132-22-9, 90-82-4]
# 24                               [125-29-1, 132-22-9]
# 25                               [125-29-1, 132-22-9]
# 26                      [125-29-1, 132-22-9, 90-82-4]
# 27                                [125-29-1, 90-82-4]
# 28                               [125-29-1, 132-22-9]
# 29                               [125-29-1, 132-22-9]
# 30                      [125-29-1, 132-22-9, 90-82-4]
# 31                                [125-29-1, 90-82-4]
# 32                                [132-22-9, 90-82-4]
# 33                                [132-22-9, 90-82-4]
# 34                                [132-22-9, 90-82-4]
# 35                            [10417-94-4, 6217-54-5]
# 36                              [50-23-7, 85721-33-1]
# 37                                [125-29-1, 90-82-4]
# 38                                [125-29-1, 90-82-4]
# 39  [1132935-63-7, 1216941-48-8, 1258226-87-7, 155...
# 40                                [125-29-1, 90-82-4]
# 41                                [125-29-1, 90-82-4]
# 42                             [24390-14-5, 564-25-0]
# 43                             [24390-14-5, 564-25-0]
# 44                            [10417-94-4, 6217-54-5]
# 45                             [24390-14-5, 564-25-0]
# 46                             [24390-14-5, 564-25-0]
# 47                             [24390-14-5, 564-25-0]
# 48                            [10417-94-4, 6217-54-5]
# 49                             [24390-14-5, 564-25-0]

# %%
merged_df['cas'] = merged_df['cas'].apply(lambda x: ', '.join(x))

# Now export to CSV without indexes
# merged_df.to_csv('path_to_your_file.csv', index=False)

# %%
merged_df
# Out:
#                                             molecule                 crp  \
# 0                  ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 1                            ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 2            AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 3              AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 4   ATROPA_BELLADONNA#CHLORPHENAMINE#PSEUDOEPHEDRINE  RESPA_PHARMACEUTIC
# ..                                               ...                 ...
# 79                           METFORMIN#ROSIGLITAZONE     GLAXOSMITHKLINE
# 80                           METFORMIN#ROSIGLITAZONE     GLAXOSMITHKLINE
# 81                           METFORMIN#ROSIGLITAZONE     GLAXOSMITHKLINE
# 82                           METFORMIN#ROSIGLITAZONE     GLAXOSMITHKLINE
# 83                                        PEMIROLAST   JOHNSON_&_JOHNSON
#
#                 intprd  drugid                       cas
# 0            ASASANTIN   15574          50-78-2, 58-32-2
# 1   LIOVEL COMBINATION   59795  111025-46-8, 850649-61-5
# 2              PREVPAC   44279    26787-78-0, 61336-70-7
# 3        OMECLAMOX-PAK   44279    26787-78-0, 61336-70-7
# 4           RESPA A.R.   91390         132-22-9, 90-82-4
# ..                 ...     ...                       ...
# 79           AVANDAMET    6050       1115-70-4, 657-24-9
# 80           AVANDAMET   49077       1115-70-4, 657-24-9
# 81           AVANDAMET   49829       1115-70-4, 657-24-9
# 82           AVANDAMET   56823     122320-73-4, 657-24-9
# 83             ALAMAST    6165   100299-08-9, 69372-19-6
#
# [84 rows x 5 columns]

# %%
new_column_order = ['molecule', 'crp', 'intprd', 'cas', 'drugid']
merged_df = merged_df[new_column_order]

# %%
merged_df.head()
# Out:
#                                            molecule                 crp  \
# 0                 ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 1                           ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 2           AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 3             AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 4  ATROPA_BELLADONNA#CHLORPHENAMINE#PSEUDOEPHEDRINE  RESPA_PHARMACEUTIC
#
#                intprd                       cas  drugid
# 0           ASASANTIN          50-78-2, 58-32-2   15574
# 1  LIOVEL COMBINATION  111025-46-8, 850649-61-5   59795
# 2             PREVPAC    26787-78-0, 61336-70-7   44279
# 3       OMECLAMOX-PAK    26787-78-0, 61336-70-7   44279
# 4          RESPA A.R.         132-22-9, 90-82-4   91390

# %%
merged_df.to_csv('merged_test.csv', index=False)

# %%
cleaned_df.head(50)
# Out:
#                                                molecule                 crp  \
# 35    1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 49                          2-PROPANOL#BENZOYL_PEROXIDE         LAB_UNKNOWN
# 65                 2-PROPANOL#KETOROLAC#POVIDONE-IODINE       TERRAIN_PHARM
# 126   ACACIA_CATECHU#CHONDROITINSULFURIC_ACID#GLUCOS...   RECKITT_BENCKISER
# 233   ACETIC_ACID#CALCIUM#FIBRINOGEN#GLYCINE#SODIUM#...   JOHNSON_&_JOHNSON
# 330   ACETYLCYSTEINE#ALLIUM_SATIVUM#ANGELICA_ARCHANG...              IOVATE
# 338   ACETYLCYSTEINE#ALLIUM_SATIVUM#ANGELICA_ARCHANG...              IOVATE
# 399   ACETYLCYSTEINE#ANGELICA_POLIMORPHA#ASCORBIC_AC...              IOVATE
# 457   ACETYLCYSTEINE#ASCORBIC_ACID#CALCIUM_LEVOFOLIN...      CENTURION_LABS
# 472   ACETYLCYSTEINE#ASCORBIC_ACID#CALCIUM_LEVOFOLIN...      CENTURION_LABS
# 500   ACETYLCYSTEINE#LEVOMEFOLIC_ACID#MECOBALAMIN#SC...              ESTEVE
# 507   ACETYLCYSTEINE#PETASITES_OFFICINALIS#PICRORRHI...              IOVATE
# 515   ACETYLSALICYLIC_ACID#CAFFEINE#CHLORPHENAMINE#P...               BAYER
# 521   ACETYLSALICYLIC_ACID#CAFFEINE#CHLORPHENAMINE#P...               BAYER
# 528   ACETYLSALICYLIC_ACID#CAFFEINE#PARACETAMOL#SALI...       GENTEX_PHARMA
# 535   ACETYLSALICYLIC_ACID#CAFFEINE#PARACETAMOL#SALI...       GENTEX_PHARMA
# 549                   ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 550                   ACETYLSALICYLIC_ACID#DIPYRIDAMOLE    BOEHRINGER_INGEL
# 558     ACETYLSALICYLIC_ACID#PHYTOSTEROLS_(UNSPECIFIED)               BAYER
# 561                                 ACICLOVIR#LIDOCAINE       ALLEGIS_PHARM
# 562                                 ACICLOVIR#LIDOCAINE       ALLEGIS_PHARM
# 827                   ALOE_BARBADENSIS#BENZOYL_PEROXIDE             MISSION
# 853   ALOE_BARBADENSIS#BENZOYL_PEROXIDE#HAMAMELIS_VI...   UNIV_MEDICAL_PROD
# 871    ALOE_BARBADENSIS#BENZOYL_PEROXIDE#SALICYLIC_ACID  WALTMAN_PHARMCEUTI
# 955   ALOE_BARBADENSIS#COLLAGEN#HYALURONIC_ACID#LIDO...         MPM_MEDICAL
# 972   ALOE_BARBADENSIS#COLLAGEN#HYALURONIC_ACID#LIDO...         MPM_MEDICAL
# 1014            ALOE_BARBADENSIS#HYALURONIC_ACID#SODIUM       NEILMED_PHARM
# 1030            ALOE_BARBADENSIS#HYDROCORTISONE#MENTHOL        WRASER_PHARM
# 1047         ALOE_BARBADENSIS#HYDROCORTISONE#PRAMOCAINE    NOVUM_PHARMA_LLC
# 1056                         ALOE_BARBADENSIS#LIDOCAINE         LAB_UNKNOWN
# 1071               ALOE_BARBADENSIS#LIDOCAINE#VITAMIN_E         MPM_MEDICAL
# 1088                            ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 1091                            ALOGLIPTIN#PIOGLITAZONE              TAKEDA
# 1179  ALTHAEA_OFFICINALIS#ARGANIA_SPINOSA#BRASSICA_C...             PURETEK
# 1188  ALTHAEA_OFFICINALIS#ARGANIA_SPINOSA#BRASSICA_C...             PURETEK
# 1251  ALUMINIUM#DIPHENHYDRAMINE#LIDOCAINE#MAGNESIUM#...        CUTIS_PHARMA
# 1300                                 AMIODARONE#GLUCOSE          PHARMEDIUM
# 1351            AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 1353            AMOXICILLIN#CLARITHROMYCIN#LANSOPRAZOLE              TAKEDA
# 1362              AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 1364              AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 1366              AMOXICILLIN#CLARITHROMYCIN#OMEPRAZOLE  CUMBERLAND_PHARMAC
# 1442                                         ARGATROBAN            NOVARTIS
# 1445                              ARTICAINE#EPINEPHRINE             PIERREL
# 1588  ASCORBIC_ACID#BETACAROTENE#BIOTIN#CARBONYL_IRO...  JUBILANT_LIFE_SCIE
# 1593  ASCORBIC_ACID#BETACAROTENE#BIOTIN#CARBONYL_IRO...  JUBILANT_LIFE_SCIE
# 1607  ASCORBIC_ACID#BETACAROTENE#BIOTIN#CARBONYL_IRO...  JUBILANT_LIFE_SCIE
# 1849  ASCORBIC_ACID#BIOTIN#CARBONYL_IRON#COBALT#COPP...             PRONOVA
# 1917  ASCORBIC_ACID#BIOTIN#CARBONYL_IRON#COPPER#CYAN...        AVION_PHARMA
# 1989  ASCORBIC_ACID#BIOTIN#CARBONYL_IRON#COPPER#CYAN...  JUBILANT_LIFE_SCIE
#
#                   intprd          cas  \
# 35      LOPROX CREAM KIT    9004-61-9
# 49    2-PROP/BENZ   L.U.      94-36-0
# 65    KETOROLAC     TEHR   74103-06-3
# 126   MOVE FREE ADV PLUS    9004-61-9
# 233             CROSSEAL    1197-18-8
# 330              GERM MD      56-85-9
# 338              GERM MD     616-91-1
# 399              COLD MD     616-91-1
# 457           PURALOR CI     616-91-1
# 472           PURALOR CI   80433-71-2
# 500   METAFOLBIC PLUS RF     616-91-1
# 507           ALLERGY MD     616-91-1
# 515          CORICIDIN D     132-22-9
# 521          CORICIDIN D      50-78-2
# 528              LEVACET     103-90-2
# 535              LEVACET      50-78-2
# 549            ASASANTIN      50-78-2
# 550            ASASANTIN      58-32-2
# 558   BAYER HEART ADVANT      50-78-2
# 561              LIDOVIR     137-58-6
# 562              LIDOVIR   59277-89-3
# 827              BP MISS      94-36-0
# 853      ACNEFREE SEVERE      94-36-0
# 871     ZAPZYT ACNE PACK      94-36-0
# 955        REGENECARE HA     137-58-6
# 972        REGENECARE HA    9004-61-9
# 1014        NASOGEL NEIL    9004-61-9
# 1030               NUZON      50-23-7
# 1047            NOVACORT      50-23-7
# 1056  LIDOCAI/ALOE  L.U.     137-58-6
# 1071          REGENECARE     137-58-6
# 1088  LIOVEL COMBINATION  111025-46-8
# 1091  LIOVEL COMBINATION  850649-61-5
# 1179  DERMACINRX PHN PAK     137-58-6
# 1188  DERMACINRX ZRM PAK     137-58-6
# 1251     FIRST-MOUTHWASH     137-58-6
# 1300  AMIODARO/GLUC PRMU    1951-25-3
# 1351             PREVPAC   26787-78-0
# 1353             PREVPAC   61336-70-7
# 1362       OMECLAMOX-PAK   26787-78-0
# 1364       OMECLAMOX-PAK   61336-70-7
# 1366       OMECLAMOX-PAK   73590-58-6
# 1442  ARGATROBAN    NOVT   74863-84-6
# 1445             ORABLOC      51-43-4
# 1588             CORVITA      65-23-6
# 1593             CORVITA      68-19-9
# 1607             CORVITA      83-88-5
# 1849          HEMAX PRNO      68-19-9
# 1917            FERIVAFA      68-19-9
# 1989              TL-HEM      68-19-9
#
#                                                  drugid
# 35                  [6807.0, 7103.0, 13469.0, 105492.0]
# 49                                            [78987.0]
# 65                                    [3422.0, 55698.0]
# 126                 [6807.0, 7103.0, 13469.0, 105492.0]
# 233                                           [51370.0]
# 330                                  [69737.0, 69738.0]
# 338                                           [95553.0]
# 399                                           [95553.0]
# 457                                           [95553.0]
# 472                                           [16915.0]
# 500                                           [95553.0]
# 507                                           [95553.0]
# 515       [66158.0, 69798.0, 83624.0, 91390.0, 91711.0]
# 521                [15574.0, 19460.0, 56276.0, 64893.0]
# 528                         [48917.0, 64433.0, 68852.0]
# 535                [15574.0, 19460.0, 56276.0, 64893.0]
# 549                [15574.0, 19460.0, 56276.0, 64893.0]
# 550                                           [15574.0]
# 558                [15574.0, 19460.0, 56276.0, 64893.0]
# 561   [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 562                [44258.0, 53498.0, 87715.0, 87725.0]
# 827                                           [78987.0]
# 853                                           [78987.0]
# 871                                           [78987.0]
# 955   [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 972                 [6807.0, 7103.0, 13469.0, 105492.0]
# 1014                [6807.0, 7103.0, 13469.0, 105492.0]
# 1030                                          [48942.0]
# 1047                                          [48942.0]
# 1056  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1071  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1088                        [48279.0, 55177.0, 59795.0]
# 1091                                          [59795.0]
# 1179  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1188  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1251  [12433.0, 15198.0, 23015.0, 44403.0, 54740.0, ...
# 1300                                          [57749.0]
# 1351                                 [44279.0, 49017.0]
# 1353                                          [44279.0]
# 1362                                 [44279.0, 49017.0]
# 1364                                          [44279.0]
# 1366                                          [34063.0]
# 1442                                  [2565.0, 73449.0]
# 1445                                 [46891.0, 98621.0]
# 1588                                [85192.0, 109953.0]
# 1593                                 [98637.0, 98648.0]
# 1607                                          [73506.0]
# 1849                                 [98637.0, 98648.0]
# 1917                                 [98637.0, 98648.0]
# 1989                                 [98637.0, 98648.0]

# %%
cleaned_df['drugid'] = cleaned_df['drugid'].apply(lambda x: ', '.join(str(int(i)) for i in x))
cleaned_df

# Now export to CSV without indexes
# merged_df.to_csv('path_to_your_file.csv', index=False)
# Out:
# /var/folders/1c/q2gw_gw92g30pjz7b1ppnlnr0000gp/T/ipykernel_82950/1008962644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['drugid'] = cleaned_df['drugid'].apply(lambda x: ', '.join(str(int(i)) for i in x))
#                                                molecule                 crp  \
# 35    1-HEXADECANOL#ANTHEMIS_NOBILIS#BUTYROSPERMUM_P...   MEDIMETRIKS_PHARM
# 49                          2-PROPANOL#BENZOYL_PEROXIDE         LAB_UNKNOWN
# 65                 2-PROPANOL#KETOROLAC#POVIDONE-IODINE       TERRAIN_PHARM
# 126   ACACIA_CATECHU#CHONDROITINSULFURIC_ACID#GLUCOS...   RECKITT_BENCKISER
# 233   ACETIC_ACID#CALCIUM#FIBRINOGEN#GLYCINE#SODIUM#...   JOHNSON_&_JOHNSON
# ...                                                 ...                 ...
# 8985            PHYTOSTEROLS_(UNSPECIFIED)#PROGESTERONE   SAYGE_BIOSCIENCES
# 9018                                        POLIDOCANOL                MERZ
# 9110       PSEUDOEPHEDRINE#SCOPOLAMINE_METHYL_HYDROXIDE              CHIESI
# 9138                                       TEMOZOLOMIDE          MERCK_&_CO
# 9175                                         VALRUBICIN  ENDO_INTERNATIONAL
#
#                   intprd         cas                     drugid
# 35      LOPROX CREAM KIT   9004-61-9  6807, 7103, 13469, 105492
# 49    2-PROP/BENZ   L.U.     94-36-0                      78987
# 65    KETOROLAC     TEHR  74103-06-3                3422, 55698
# 126   MOVE FREE ADV PLUS   9004-61-9  6807, 7103, 13469, 105492
# 233             CROSSEAL   1197-18-8                      51370
# ...                  ...         ...                        ...
# 8985  BALANCE HRT NATURA     57-83-0                      40649
# 9018             ASCLERA   9002-92-0                      88713
# 9110            ALLERX D     90-82-4        13110, 91390, 91396
# 9138        TEMODAL M-CO  85622-93-1                       4529
# 9175        VALSTAR ENDN  56124-62-0                      11295
#
# [441 rows x 5 columns]

# %%
cleaned_df.to_csv('final_cleaned.csv', index=False)
